# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch
import pandas as pd
from preprocessing_algorithms import*

# %%
# load the T5 model and tokenizer
model_name = 't5-small'
tokenizer = T5Tokenizer.from_pretrained(model_name, model_max_length=4214)
model = T5ForConditionalGeneration.from_pretrained(model_name, max_length=4214)


# \Local\Programs\Python\Python310\lib\site-packages\transformers\models\t5\tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# to fix this use model_max_length=512 and  max_length=512

# %%
data = pd.read_csv('DUC/Duc_first_reference/main_dataset/Duc_dataset_first_ref_summary.csv')
text = data.iloc[0,0]
text
# Out:
# "\r\nCambodian leader Hun Sen on Friday rejected opposition parties' demands \r\nfor talks outside the country, accusing them of trying to ``internationalize'' \r\nthe political crisis. Government and opposition parties have asked \r\nKing Norodom Sihanouk to host a summit meeting after a series of post-election \r\nnegotiations between the two opposition groups and Hun Sen's party \r\nto form a new government failed. Opposition leaders Prince Norodom \r\nRanariddh and Sam Rainsy, citing Hun Sen's threats to arrest opposition \r\nfigures after two alleged attempts on his life, said they could not \r\nnegotiate freely in Cambodia and called for talks at Sihanouk's residence \r\nin Beijing. Hun Sen, however, rejected that. ``I would like to make \r\nit clear that all meetings related to Cambodian affairs must be conducted \r\nin the Kingdom of Cambodia,'' Hun Sen told reporters after a Cabinet \r\nmeeting on Friday. ``No-one should internationalize Cambodian affairs. \r\nIt is detrimental to the sovereignty of Cambodia,'' he said. Hun Sen's \r\nCambodian People's Party won 64 of the 122 parliamentary seats in \r\nJuly's elections, short of the two-thirds majority needed to form \r\na government on its own. Ranariddh and Sam Rainsy have charged that \r\nHun Sen's victory in the elections was achieved through widespread \r\nfraud. They have demanded a thorough investigation into their election \r\ncomplaints as a precondition for their cooperation in getting the \r\nnational assembly moving and a new government formed. Hun Sen said \r\non Friday that the opposition concerns over their safety in the country \r\nwas ``just an excuse for them to stay abroad.'' Both Ranariddh and \r\nSam Rainsy have been outside the country since parliament was ceremonially \r\nopened on Sep. 24. Sam Rainsy and a number of opposition figures have \r\nbeen under court investigation for a grenade attack on Hun Sen's Phnom \r\nPenh residence on Sep. 7. Hun Sen was not home at the time of the \r\nattack, which was followed by a police crackdown on demonstrators \r\ncontesting Hun Sen's election victory. The Sam Rainsy Party, in a \r\nstatement released Friday, accused Hun Sen of being ``unwilling to \r\nmake any compromise'' on negotiations to break the deadlock. ``A meeting \r\noutside Cambodia, as suggested by the opposition, could place all \r\nparties on more equal footing,'' said the statement. ``But the ruling \r\nparty refuses to negotiate unless it is able to threaten its negotiating \r\npartners with arrest or worse.'' \r\n \r\nKing Norodom Sihanouk has declined requests to chair a summit of Cambodia's \r\ntop political leaders, saying the meeting would not bring any progress \r\nin deadlocked negotiations to form a government. Cambodian leader \r\nHun Sen's ruling party and the two-party opposition had called on \r\nthe monarch to lead top-level talks, but disagreed on its location. \r\n``Papa will not preside over any summit meeting between the three \r\nparties, whether it is held in Phnom Penh or Beijing, because such \r\na meeting will certainly achieve no result,'' Sihanouk wrote in an \r\nOct. 17 letter to his son, Prince Norodom Ranariddh, leader of the \r\nsenior opposition FUNCINPEC party. A copy of the letter was obtained \r\nThursday. In it, the king called on the three parties to make compromises \r\nto end the stalemate: ``Papa would like to ask all three parties to \r\ntake responsibility before the nation and the people.'' Hun Sen used \r\nThursday's anniversary of a peace agreement ending the country's civil \r\nwar to pressure the opposition to form a coalition government with \r\nhis party. ``Only those who want to prolong the anarchy and instability \r\nprevent efforts to set up a new government,'' Hun Sen said in a televised \r\nspeech marking the anniversary of the 1991 Paris Peace Accords. Hun \r\nSen's party won 64 of the 122 seats in parliament in July's national \r\nelection, but not the two-thirds majority necessary to  ...

# %%
sentences,filtered_sentences = preprocessing_text_with_spacy(text,remove_stopwords=True,lemmatization= True)

# %%
for i in filtered_sentences:
    text += i

# %%
data['Original Summary'][0]
# Out:
# "Prospects were dim for resolution of the political crisis in Cambodia in October 1998.\r\nPrime Minister Hun Sen insisted that talks take place in Cambodia while opposition leaders Ranariddh and Sam Rainsy, fearing arrest at home, wanted them abroad.\r\nKing Sihanouk declined to chair talks in either place.\r\nA U.S. House resolution criticized Hun Sen's regime while the opposition tried to cut off his access to loans.\r\nBut in November the King announced a coalition government with Hun Sen heading the executive and Ranariddh leading the parliament.\r\nLeft out, Sam Rainsy sought the King's assurance of Hun Sen's promise of safety and freedom for all politicians.\r\n"

# %%
# tokenize the text and generate the summary
inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", truncation=True, padding=True)

# %%
summary_ids = model.generate(inputs, num_beams=4, max_length=100, early_stopping=True)

# %%
len(summary_ids[0])
# Out:
# 64

# %%
for i,j in enumerate(summary_ids[0]):
    print(j, tokenizer.decode(summary_ids[0][i], skip_special_tokens=True))
# Out:
# tensor(0) <pad>
# tensor(3)
# tensor(1765) king
# tensor(3701) nor
# tensor(32) o
# tensor(5012) dom
# tensor(108) si
# tensor(2618) han
# tensor(32) o
# tensor(1598) uk
# tensor(845) says
# tensor(3)
# tensor(88) he
# tensor(19) is
# tensor(3)
# tensor(31) '
# tensor(25866) strong
# tensor(120) ly
# tensor(1638) interested
# tensor(31) '
# tensor(16) in
# tensor(3)
# tensor(9) a
# tensor(126) new
# tensor(789) government
# tensor(3)
# tensor(5) .
# tensor(3)
# tensor(88) he
# tensor(845) says
# tensor(8) the
# tensor(8263) opposition
# tensor(19) is
# tensor(1119) trying
# tensor(12) to
# tensor(3)
# tensor(31) '
# tensor(27817) international
# tensor(1737) ize
# tensor(31) '
# tensor(8) the
# tensor(1827) political
# tensor(5362) crisis
# tensor(3)
# tensor(5) .
# tensor(3)
# tensor(88) he
# tensor(845) says
# tensor(8) the
# tensor(8263) opposition
# tensor(19) is
# tensor(3)
# tensor(31) '
# tensor(202) un
# tensor(8894) will
# tensor(53) ing
# tensor(12) to
# tensor(143) make
# tensor(136) any
# tensor(12326) compromise
# tensor(31) '
# tensor(3)
# tensor(5) .
# tensor(1) </s>

# %%
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
summary
# Out:
# "king norodom sihanouk says he is'strongly interested' in a new government. he says the opposition is trying to 'internationalize' the political crisis. he says the opposition is 'unwilling to make any compromise'."

# %%
# score each sentence in the original text based on how closely it matches the summary
sentences = text.split('. ')
scores = []
for sentence in sentences:
    input_text = "summarize: " + sentence
    input_ids = tokenizer.encode(input_text, return_tensors='pt')
    summary_ids = model.generate(input_ids, num_beams=4, max_length=20, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    if summary:
        score = len(set(summary.split()).intersection(set(text.split()))) / len(set(summary.split()))
        scores.append(score)
    else:
        scores.append(0.0)

# %%
summary_size=5

# %%
sentence_scores = []
# print the scores for each sentence
for i, sentence in enumerate(sentences):
    print(f"Sentence {i+1}: {sentence}")
    sentence_scores.append(scores[i])
    print(f"Score: {scores[i]}")
len(sentence_scores)
# Out:
# Sentence 1:
# Cambodian leader Hun Sen on Friday rejected opposition parties' demands
# for talks outside the country, accusing them of trying to ``internationalize''
# the political crisis
# Score: 0.75
# Sentence 2: Government and opposition parties have asked
# King Norodom Sihanouk to host a summit meeting after a series of post-election
# negotiations between the two opposition groups and Hun Sen's party
# to form a new government failed
# Score: 1.0
# Sentence 3: Opposition leaders Prince Norodom
# Ranariddh and Sam Rainsy, citing Hun Sen's threats to arrest opposition
# figures after two alleged attempts on his life, said they could not
# negotiate freely in Cambodia and called for talks at Sihanouk's residence
# in Beijing
# Score: 0.8888888888888888
# Sentence 4: Hun Sen, however, rejected that
# Score: 1.0
# Sentence 5: ``I would like to make
# it clear that all meetings related to Cambodian affairs must be conducted
# in the Kingdom of Cambodia,'' Hun Sen told reporters after a Cabinet
# meeting on Friday
# Score: 0.9333333333333333
# Sentence 6: ``No-one should internationalize Cambodian affairs
# Score: 0.8
# Sentence 7:
# It is detrimental to the sovereignty of Cambodia,'' he said
# Score: 1.0
# Sentence 8: Hun Sen's
# Cambodian People's Party won 64 of the 122 parliamentary seats in
# July's elections, short of the two-thirds majority needed to form
# a government on its own
# Score: 0.9285714285714286
# Sentence 9: Ranariddh and Sam Rainsy have charged that
# Hun Sen's victory in the elections was achieved through widespread
# fraud
# Score: 1.0
# Sentence 10: They have demanded a thorough investigation into their election
# complaints as a precondition for their cooperation in getting the
# national assembly moving and a new government formed
# Score: 1.0
# Sentence 11: Hun Sen said
# on Friday that the opposition concerns over their safety in the country
# was ``just an excuse for them to stay abroad.'' Both Ranariddh and
# Sam Rainsy have been outside the country since parliament was ceremonially
# opened on Sep
# Score: 1.0
# Sentence 12: 24
# Score: 1.0
# Sentence 13: Sam Rainsy and a number of opposition figures have
# been under court investigation for a grenade attack on Hun Sen's Phnom
# Penh residence on Sep
# Score: 1.0
# Sentence 14: 7
# Score: 1.0
# Sentence 15: Hun Sen was not home at the time of the
# attack, which was followed by a police crackdown on demonstrators
# contesting Hun Sen's election victory
# Score: 1.0
# Sentence 16: The Sam Rainsy Party, in a
# statement released Friday, accused Hun Sen of being ``unwilling to
# make any compromise'' on negotiations to break the deadlock
# Score: 0.9166666666666666
# Sentence 17: ``A meeting
# outside Cambodia, as suggested by the opposition, could place all
# parties on more equal footing,'' said the statement
# Score: 1.0
# Sentence 18: ``But the ruling
# party refuses to negotiate unless it is able to threaten its negotiating
# partners with arrest or worse.''
#
# King Norodom Sihanouk has declined requests to chair a summit of Cambodia's
# top political leaders, saying the meeting would not bring any progress
# in deadlocked negotiations to form a government
# Score: 0.9166666666666666
# Sentence 19: Cambodian leader
# Hun Sen's ruling party and the two-party opposition had called on
# the monarch to lead top-level talks, but disagreed on its location
# Score: 0.9230769230769231
# Sentence 20:
# ``Papa will not preside over any summit meeting between the three
# parties, whether it is held in Phnom Penh or Beijing, because such
# a meeting will certainly achieve no result,'' Sihanouk wrote in an
# Oct
# Score: 0.9285714285714286
# Sentence 21: 17 letter to his son, Prince Norodom Ranariddh, leader of the
# senior opposition FUNCINPEC party
# Score: 1.0
# Sentence 22: A copy of the letter was obtained
# Thursday
# Score: 1.0
# Sentence 23: In it, the king called on the three parties to make compromises
# to end the stalemate: ``Papa would like to ask all three parties to
# take responsibility before the nation and the people.'' Hun Sen used
# Thursday's anniversary of a peace agreement ending the country's civil
# war to pressure the opposition to form a coalition government with
# his party
# Score: 1.0
# Sentence 24: ``Only those who want to prolong the anarchy and instability
# prevent efforts to set up a new government,'' Hun Sen said in a televised
# speech marking the anniversary of the 1991 Paris Peace Accords
# Score: 0.9230769230769231
# Sentence 25: Hun
# Sen's party won 64 of the 122 seats in parliament in July's national
# election, but not the two-thirds majority necessary to form a government
# on its own
# Score: 1.0
# Sentence 26: Opposition parties led by Ranariddh and former finance
# minister Sam Ram Rainsy have refused to enter into a coalition with
# Hun Sen until their allegations of election fraud have been thoroughly
# investigated
# Score: 1.0
# Sentence 27: International monitors said the election was relatively
# free and fair
# Score: 0.9090909090909091
# Sentence 28: Hun Sen said his current government would remain in
# power as long as the opposition refused to form a new one
# Score: 1.0
# Sentence 29: Ranariddh
# and Sam Rainsy have remained outside the country since the Sept
# Score: 1.0
# Sentence 30: 24
# ceremonial convening of parliament
# Score: 1.0
# Sentence 31: Citing Hun Sen's threats to arrest
# opposition politicians following two alleged attempts on his life,
# Ranariddh and Sam Rainsy have said they do not feel safe negotiating
# inside the country and asked the king to chair the summit at his residence
# in Beijing
# Score: 1.0
# Sentence 32: Hun Sen has rejected the opposition's reservations, saying
# it would be inappropriate to hold a summit outside the country
# Score: 0.9230769230769231
# Sentence 33: Negotiations
# so far have proved fruitless except for the opening of parliament
# after a Sept
# Score: 1.0
# Sentence 34: 22 summit led by the king
# Score: 1.0
# Sentence 35: Hun Sen implied Thursday
# that the opposition failed to follow through on promises made at the
# summit
# Score: 1.0
# Sentence 36: ``If those results are strictly respected, there seems no
# reason to hold another summit,'' Hun Sen said in a speech on the anniversary
# of the 1991 Paris Peace Accords
# Score: 0.8571428571428571
# Sentence 37: Sihanouk is reportedly set to fly
# to Beijing next month to receive medical treatment from his Chinese
# doctors
# Score: 0.9230769230769231
# Sentence 38: The 75-year-old monarch suffers from a variety ailments and
# periodically makes extended trips to Beijing
# Score: 0.9230769230769231
# Sentence 39: He was diagnosed with
# colon cancer in 1993, but it has since gone into remission
# Score: 0.8571428571428571
# Sentence 40: In September,
# thousands of people filled the streets of Phnom Penh to protest against
# the alleged election fraud
# Score: 0.9230769230769231
# Sentence 41: Hun Sen ordered police to break up the
# demonstrations
# Score: 1.0
# Sentence 42: At least four demonstrators were killed by police,
# but the discovery of more than 20 bodies in the aftermath has prompted
# speculation that the death tally could be much higher
# Score: 0.9333333333333333
# Sentence 43: In his speech,
# Hun Sen blamed the violence on opposition leaders, saying the demonstrations
# instigated social and economic chaos
# Score: 0.9230769230769231
# Sentence 44:
#
# Cambodia's two-party opposition asked the Asian Development Bank Monday
# to stop providing loans to the incumbent government, which it calls
# illegal
# Score: 0.9230769230769231
# Sentence 45: Negotiations to form the next government have become deadlocked,
# and opposition party leaders Prince Norodom Ranariddh and Sam Rainsy
# are out of the country following threats of arrest from strongman
# Hun Sen
# Score: 1.0
# Sentence 46: Hun Sen complained Monday that the opposition was trying
# to make its members' return an international issue
# Score: 1.0
# Sentence 47: Hun Sen's ruling
# party narrowly won a majority in elections in July, but the opposition
# _ claiming widespread intimidation and fraud _ has denied Hun Sen
# the two-thirds vote in parliament required to approve the next government
# Score: 0.9166666666666666
# Sentence 48:
# Meanwhile, it says, the old government is holding power illegally
# Score: 0.75
# Sentence 49:
# Ranariddh and Sam Rainsy renewed their international lobbying campaign
# against the old government Monday in a letter to ADB President Mitsuo
# Sato calling for the bank to stop lending money to it
# Score: 1.0
# Sentence 50: ``We respectfully
# advise the Asian Development Bank not to provide any new loans to
# the current regime in Cambodia,'' the two party leaders wrote
# Score: 0.9285714285714286
# Sentence 51: ``At
# best the current regime could be considered a caretaker government
# as it has not been approved by the National Assembly.'' After a meeting
# between Hun Sen and the new French ambassador to Cambodia, Hun Sen
# aide Prak Sokhonn said the Cambodian leader had repeated calls for
# the opposition to return, but expressed concern that the international
# community may be asked for security guarantees
# Score: 0.8181818181818182
# Sentence 52: ``There have been
# reports that there is an attempt to internationalize the return of
# those members of parliament on the excuse of security problems,''
# Prak Sokhonn said
# Score: 1.0
# Sentence 53: ``Some (opposition politicians) have wanted the
# United Nations to help guarantee a safe return for them.'' The U.N
# Score: 0.9285714285714286
# Sentence 54:
# secretary-general's representative office in Phnom Penh provided monitors
# to opposition politicians after they returned to Cambodia to participate
# in the July election
# Score: 1.0
# Sentence 55: The monitoring ended Sept
# Score: 1.0
# Sentence 56: 30
# Score: 1.0
# Sentence 57: ``Our office
# has not received any official request for that operation to be started
# up again,'' U.N
# Score: 0.875
# Sentence 58: diplomat Jonathan Prentice said Monday in reaction
# to Prak Sokhonn's statement
# Score: 0.875
# Sentence 59: The opposition has insisted that any
# further talks on the next government must take place outside the country,
# but the ruling party has rejected allegations of intimidation and
# recently guaranteed opposition members' safety inside the country
# Score: 0.9285714285714286
# Sentence 60:
# Diplomatic efforts to revive the stalled talks appeared to bear fruit
# Monday as Japanese Foreign Affairs Secretary of State Nobutaka Machimura
# said King Norodom Sihanouk has called on Ranariddh and Sam Rainsy
# to return to Cambodia
# Score: 0.75
# Sentence 61: Less than two weeks after abandoning hope that
# he could influence the parties to reach a compromise, Sihanouk is
# now ``strongly interested'' in presiding over a summit meeting of
# the three party leaders in Cambodia, Machimura said
# Score: 0.75
# Sentence 62:
#
# Cambodia's ruling party responded Tuesday to criticisms of its leader
# in the U.S
# Score: 0.8181818181818182
# Sentence 63: Congress with a lengthy defense of strongman Hun Sen's
# human rights record
# Score: 0.9
# Sentence 64: The Cambodian People's Party criticized a non-binding
# resolution passed earlier this month by the U.S
# Score: 0.9166666666666666
# Sentence 65: House of Representatives
# calling for an investigation into violations of international humanitarian
# law allegedly committed by Hun Sen
# Score: 0.9375
# Sentence 66: Events mentioned in the resolution
# include Hun Sen's coup last year against his co-prime minister, Prince
# Norodom Ranariddh, and his violent crackdown in September against
# anti-government demonstrations
# Score: 0.9285714285714286
# Sentence 67: A copy of the resolution has since
# been submitted to the U.S
# Score: 1.0
# Sentence 68: Senate Committee on Foreign Relations
# Score: 0.8
# Sentence 69:
# ``The CPP would like to launch an appeal to U.S
# Score: 1.0
# Sentence 70: senators to wisely
# and realistically consider this draft resolution and give justice
# to the CPP, Hun Sen and the Cambodian people by not approving it,''
# the party said in a statement
# Score: 1.0
# Sentence 71: It defended Hun Sen's ouster of Ranariddh
# as a proper response to the prince's attempts at the time to negotiate
# the defections of senior Khmer Rouge rebels
# Score: 1.0
# Sentence 72: It also repeated claims
# that the prince's party had moved rebel soldiers into Phnom Penh,
# a contention that remains unproved
# Score: 1.0
# Sentence 73: The killings of nearly 100 of
# Ranariddh's supporters documented by U.N
# Score: 0.9
# Sentence 74: human rights workers in
# the aftermath of the coup were dismissed by the CPP as mostly fabrications
# meant to distort the political situation
# Score: 1.0
# Sentence 75: Ranariddh and his core supporters
# did not return to Cambodia until a few months before an election in
# July this year that the ruling party narrowly won
# Score: 1.0
# Sentence 76: Ranariddh and his
# opposition ally, Sam Rainsy, refused to accept the election results,
# alleging widespread intimidation and fraud by the CPP
# Score: 1.0
# Sentence 77: When their
# claims were dismissed by a Hun Sen-friendly court, they rallied their
# supporters into the streets of Phnom Penh
# Score: 0.9090909090909091
# Sentence 78: After two weeks of tolerating
# the demonstrations, Hun Sen ordered a violent crackdown that resulted
# in the deaths of at least four protesters
# Score: 0.9230769230769231
# Sentence 79: U.N
# Score: 1.0
# Sentence 80: human rights workers
# later discovered more than 20 bodies _ many bearing signs of torture
# _ in and around the capital, prompting speculation that the death
# toll could be much higher
# Score: 0.8666666666666667
# Sentence 81: The ruling party supported the police action
# in its statement, noting that public property was damaged by protesters
# and that grenades were thrown at Hun Sen's home after Sam Rainsy suggested
# in a speech that the U.S
# Score: 0.9375
# Sentence 82: government should fire cruise missiles at
# Hun Sen
# Score: 1.0
# Sentence 83: The opposition claims the grenade attack was staged as an
# excuse to begin the crackdown
# Score: 1.0
# Sentence 84: ``The leaders of illegal demonstrations
# are the ones who must bear responsibility for the consequences deriving
# from the protest,'' the CPP said Tuesday, referring to the deadly
# violence as ``minor incidents.'' The ruling party also reminded the
# United States that Washington supported a Cambodian exile government
# dominated by the brutal Khmer Rouge in the 1980s
# Score: 0.8666666666666667
# Sentence 85: The Khmer Rouge
# was responsible for the deaths of as many as 2 million people during
# the guerrilla group's 1975-79 rule of Cambodia
# Score: 1.0
# Sentence 86: After a series of
# border clashes, the Khmer Rouge was ousted from power by an invading
# Vietnamese army that set up a surrogate Cambodian communist government
# later led by Hun Sen
# Score: 1.0
# Sentence 87: The ruling party accused U.S
# Score: 0.7142857142857143
# Sentence 88: policy-makers
# of not taking timely action to save the Cambodian people from the
# Khmer Rouge
# Score: 1.0
# Sentence 89: ``They must not make unjust accusations against those
# who led the struggle to liberate the people from genocide,'' it added
# Score: 0.9285714285714286
# Sentence 90:
#
# Cambodia's leading opposition party ruled out sharing the presidency
# of Parliament with its arch foe Saturday, insisting it alone must
# occupy the top position in the legislative body
# Score: 0.9230769230769231
# Sentence 91: Disputes over the
# presidency have been a major stumbling block in talks between the
# two-party opposition bloc and the Cambodian People's Party to form
# a new government
# Score: 1.0
# Sentence 92: Cambodian leader Hun Sen, who heads the CPP, has
# offered to share the legislature's top job with the royalist FUNCINPEC
# party of Prince Norodom Ranariddh in order to break the impasse
# Score: 0.9230769230769231
# Sentence 93: The
# prince's party, in a statement dated Friday and seen Saturday, said
# such a scenario was unconstitutional
# Score: 1.0
# Sentence 94: ``Co-sharing anything with the
# CPP means surrendering full power to them
# Score: 0.8181818181818182
# Sentence 95: Furthermore, such a proposal
# is unconstitutional,'' the faxed statement said
# Score: 1.0
# Sentence 96: The royalist party
# also rejected Hun Sen's calls to hold bilateral talks, insisting that
# Ranariddh's main ally Sam Rainsy also be included
# Score: 0.9166666666666666
# Sentence 97: ``No party with
# seats at the National Assembly should be left out if transparency
# and a check and balance system is to be used in government,'' the
# statement said, adding that the Sam Rainsy Party should also be given
# chairmanship of one of the national assembly's nine commissions
# Score: 0.9230769230769231
# Sentence 98: Noting
# that FUNCINPEC allowed the CPP to hold the presidency despite its
# win in the 1993 general elections, the statement said it was now its
# turn to take the post
# Score: 1.0
# Sentence 99: In the most recent elections, held in July,
# Hun Sen's party collected 64 of the 122 parliamentary seats, but was
# short of the two-thirds majority needed to set up a new government
# Score: 0.9166666666666666
# Sentence 100:
# Fearing arrest, many opposition members of Parliament left Cambodia
# after the ceremonial opening of the National Assembly on Sep
# Score: 0.9333333333333333
# Sentence 101: 24
# Score: 1.0
# Sentence 102:
# A series of negotiations to forge a new government have failed
# Score: 1.0
# Sentence 103: The
# talks have been complicated by the CPP-FUNCINPEC quarrel over the
# Parliament's top job
# Score: 1.0
# Sentence 104: Hun Sen's party recently called on Ranariddh
# to return to the negotiation table and said it was willing to make
# an ``appropriate concession'' to break the deadlock over forming a
# government
# Score: 0.9090909090909091
# Sentence 105: FUNCINPEC has demanded from Hun Sen written guarantees
# for the safety of its members and activities as a precondition for
# re-entering negotiations
# Score: 1.0
# Sentence 106:
#
# Cambodia's bickering political parties broke a three-month deadlock
# Friday and agreed to a coalition government leaving strongman Hun
# Sen as sole prime minister, King Norodom Sihanouk announced
# Score: 1.0
# Sentence 107: In a
# long-elusive compromise, opposition leader Prince Norodom Ranariddh
# will become president of the National Assembly resulting from disputed
# elections in July, even though Hun Sen's party holds a majority of
# 64 seats in the 122-member chamber
# Score: 1.0
# Sentence 108: Hun Sen's Cambodian People's Party
# dropped insistence on a joint assembly chairmanship shared by Ranariddh
# and party boss Chea Sim, the current speaker
# Score: 1.0
# Sentence 109: It was one of the main
# stumbling blocks in months of discord
# Score: 1.0
# Sentence 110: Instead, Sihanouk announced,
# the constitution will be modified to create a new Senate, which Chea
# Sim will head
# Score: 1.0
# Sentence 111: Chea Sim will still serve as acting head of state during
# the king's frequent absences from the country
# Score: 1.0
# Sentence 112: ``The major political
# crisis in the country has been resolved and the political deadlock
# facing the nation has also come to an end,'' the king said in his
# statement
# Score: 0.9230769230769231
# Sentence 113: The Senate will initially be appointed by the king
# Score: 1.0
# Sentence 114: The
# agreement did not say how many seats there would be, nor how they
# would be divided
# Score: 1.0
# Sentence 115: The parties will hammer out details later
# Score: 1.0
# Sentence 116: Pok Than,
# one of Ranariddh's negotiators, said the Senate would serve a mostly
# advisory role to the assembly
# Score: 0.8888888888888888
# Sentence 117: The senior Senate leaders will join
# those of the assembly, the prime minister and the country's top two
# Buddhist monks in a delicate balance of power on the council that
# will choose Cambodia's next king after Sihanouk dies
# Score: 0.9230769230769231
# Sentence 118: The two parties
# said that the assembly would convene again Nov
# Score: 1.0
# Sentence 119: 25
# Score: 1.0
# Sentence 120: The agreement
# came surprisingly quickly following Ranariddh's return Thursday from
# Thailand, where he had been holed up with other opposition figures
# for weeks amid fears for their safety if they stayed in Cambodia
# Score: 0.9
# Sentence 121:
# The deal should allow rapid formation of a government between the
# CPP and Ranariddh's royalist FUNCINPEC to allow international donors
# and businesses to again operate in the poverty-stricken country, which
# is in desperate need of aid
# Score: 1.0
# Sentence 122: It could also hasten Cambodia's entry
# into the Association of Southeast Asian Nations, put on hold last
# year after Hun Sen deposed Ranariddh as co-prime minister in a bloody
# coup
# Score: 0.8333333333333334
# Sentence 123: Earlier, as both sides arrived at the Royal Palace for a second
# day of meetings, Sihanouk said they had agreed in principle to form
# a coalition and made ``important concessions.'' The king, the sole
# force in Cambodian politics able to broker a deal, pressured both
# sides to reach agreement before he leaves Saturday for medical treatment
# in Beijing
# Score: 1.0
# Sentence 124: Sihanouk reported that Hun Sen responded positively to
# a request by Ranariddh for five of his key supporters to receive political
# pardons
# Score: 1.0
# Sentence 125: All five were convicted of political crimes by courts that
# are widely seen as loyal to Hun Sen
# Score: 1.0
# Sentence 126: The king has powers to grant
# pardons, but has awaited agreement from Hun Sen in politically sensitive
# cases
# Score: 0.9166666666666666
# Sentence 127: Former battlefield enemies, the CPP and FUNCINPEC have been
# at loggerheads since the CPP narrowly won parliamentary elections
# in July
# Score: 1.0
# Sentence 128: The vote failed to put an end to instability that followed
# last year's coup
# Score: 1.0
# Sentence 129: The CPP fell short of the two-thirds majority needed
# to form a government alone
# Score: 1.0
# Sentence 130: Ranariddh's party and opposition ally
# Sam Rainsy held back their support, claiming the CPP won due to fraud
# and intimidation
# Score: 0.8571428571428571
# Sentence 131: The opposition organized protests in Phnom Penh
# seeking Hun Sen's ouster that were violently dispersed
# Score: 1.0
# Sentence 132: Sam Rainsy,
# under investigation by a Phnom Penh court for his role in the demonstrations,
# has remained abroad
# Score: 1.0
# Sentence 133: His 15 seats in the 122-seat assembly are irrelevant
# to forming a working government
# Score: 1.0
# Sentence 134:
#
# Cambodian politicians expressed hope Monday that a new partnership
# between the parties of strongman Hun Sen and his rival, Prince Norodom
# Ranariddh, in a coalition government would not end in more violence
# Score: 0.9230769230769231
# Sentence 135:
# Hun Sen and Ranariddh, co-prime ministers in a coalition formed in
# 1993 after a landmark U.N.-sponsored election, often clashed over
# power-sharing and the integration of guerrilla fighters from the crumbling
# Khmer Rouge
# Score: 1.0
# Sentence 136: Their arguments turned bloody last year when Hun Sen
# ousted Ranariddh in a coup
# Score: 1.0
# Sentence 137: The prince fled Cambodia and did not return
# until a few months before elections in July
# Score: 1.0
# Sentence 138: Hun Sen's Cambodian People's
# Party narrowly won the polls, but a strong second-place finish by
# Ranariddh's FUNCINPEC gave the royalist party leverage in post-election
# negotiations
# Score: 1.0
# Sentence 139: After a three-month impasse, they agreed last week to
# a coalition deal that will make Hun Sen sole prime minister and Ranariddh
# president of the National Assembly
# Score: 1.0
# Sentence 140: ``This will not be a repetition
# of 1993 because there will not be two prime ministers,'' said Hun
# Sen aide Prak Sokhon, who attended last week's summit
# Score: 0.9230769230769231
# Sentence 141: ``When we had
# two prime ministers, everything moved very slowly and decisions were
# made more politically than technically.'' Ranariddh said Saturday
# that the two parties agreed to keep the ministries of interior and
# defense under co-ministers
# Score: 0.9333333333333333
# Sentence 142: Senior FUNCINPEC official Ahmad Yahya
# revealed Monday that it was also agreed that the CPP would control
# the foreign affairs and finance portfolios
# Score: 0.9230769230769231
# Sentence 143: FUNCINPEC will take justice
# and information
# Score: 1.0
# Sentence 144: The parties are to form working groups this week
# to divide remaining government posts and draft a constitutional amendment
# to form a new Senate
# Score: 1.0
# Sentence 145: Hun Sen and Ranariddh are scheduled to meet
# Nov
# Score: 0.9
# Sentence 146: 23 _ two days before parliament reopens _ to review the results
# of the working groups and give their final approval, Ahmad Yahya said
# Score: 1.0
# Sentence 147:
# Their ability to repair their relationship and work together will
# be the key to a stable coalition
# Score: 1.0
# Sentence 148: ``I consider this a remarriage,''
# Ahmad Yahya said
# Score: 0.75
# Sentence 149: ``They have to be careful with the way they work
# and what they say
# Score: 1.0
# Sentence 150: They will have to compromise to achieve results.''
# Ranariddh's ally, Sam Rainsy, whose party placed a distant third in
# the election, was left out of last week's deal
# Score: 1.0
# Sentence 151: Sam Rainsy, a virulent
# critic of Hun Sen, and his party's 14 other members of parliament
# have remained outside Cambodia since September amid fears for their
# security
# Score: 1.0
# Sentence 152: In a letter to King Norodom Sihanouk released Monday, Sam
# Rainsy complained that Hun Sen had not responded to his queries on
# security, making it unsafe for his people to return for the reconvening
# of parliament
# Score: 0.9090909090909091
# Sentence 153: Sam Rainsy said he had been told by Ranariddh that
# his party and former Khmer Rouge guerrillas had been implicated by
# Hun Sen in a rocket attack on the Sept
# Score: 1.0
# Sentence 154: 24 opening of parliament
# Score: 1.0
# Sentence 155:
# Authorities have called it an assassination attempt on Hun Sen
# Score: 0.875
# Sentence 156: A
# police general investigating the attack said Monday that likely suspects
# have been identified, but he would not reveal names or their political
# affiliation
# Score: 0.8571428571428571
# Sentence 157:
#
# Cambodian leader Hun Sen has guaranteed the safety and political freedom
# of all politicians, trying to ease the fears of his rivals that they
# will be arrested or killed if they return to the country
# Score: 0.9333333333333333
# Sentence 158: The assurances
# were aimed especially at Sam Rainsy, leader of a vocally anti-Hun
# Sen opposition party, who was forced to take refuge in the U.N
# Score: 1.0
# Sentence 159: offices
# in September to avoid arrest after Hun Sen accused him of being behind
# a plot against his life
# Score: 1.0
# Sentence 160: Sam Rainsy and the 14 members of parliament
# from his party have been holed up overseas for two months
# Score: 1.0
# Sentence 161: But a deal
# reached between Hun Sen and his chief rival, Prince Norodom Ranariddh,
# on forming a new government last week has opened the door for their
# return
# Score: 0.875
# Sentence 162: In a letter to King Norodom Sihanouk _ the prince's father
# and Cambodia's head of state _ that was broadcast on television Tuesday,
# Hun Sen said that guarantees of safety extended to Ranariddh applied
# to all politicians
# Score: 0.9285714285714286
# Sentence 163: His assurances come a week before the first session
# of Cambodia's new parliament, the National Assembly
# Score: 1.0
# Sentence 164: Sam Rainsy said
# Wednesday that he was unsatisfied with the guarantee
# Score: 0.8888888888888888
# Sentence 165: He said it contained
# indirect language and loopholes that suggest he and his Sam Rainsy
# Party members are still under threat of arrest from Hun Sen's ruling
# party
# Score: 1.0
# Sentence 166: ``It should be easy for them to say, `Rainsy and the SRP members
# of the assembly have no charges against them and will not be arrested,'''
# the opposition leader said in a statement
# Score: 0.8461538461538461
# Sentence 167: ``But instead they make
# roundabout statements, full of loopholes that can easily be exploited
# by a legal system that is completely in their control.'' Ranariddh
# told reporters Wednesday that he believed it was safe for Sam Rainsy
# in Cambodia
# Score: 0.8333333333333334
# Sentence 168: Speaking upon his return from a brief stay in Bangkok,
# the prince said he would soon meet with Hun Sen to discuss the apportioning
# of ministries in the new coalition government
# Score: 1.0
# Sentence 169: Last week, Hun Sen's
# Cambodian People's Party and Ranariddh's FUNCINPEC party agreed to
# form a coalition that would leave Hun Sen as sole prime minister and
# make the prince president of the National Assembly
# Score: 1.0
# Sentence 170: The deal assures
# the two-thirds vote in parliament needed to approve a new government
# Score: 1.0
# Sentence 171:
# The men served as co-prime ministers until Hun Sen overthrew Ranariddh
# in a coup last year
# Score: 0.9090909090909091
# Sentence 172: ``I think Hun Sen has got everything
# Score: 1.0
# Sentence 173: He's got
# the premiership and legitimacy through the election and recognition
# from his majesty the king
# Score: 0.8333333333333334
# Sentence 174: I don't think there is any benefit for
# Hun Sen to cause instability for our country,'' Ranariddh said
# Score: 1.0
# Sentence 175: The
# prince also said that his top general, Nhek Bunchhay, would not be
# given back his previous position as the second-ranking general in
# the Cambodian military's general staff
# Score: 1.0
# Sentence 176: Nhek Bunchhay's outnumbered
# forces in the capital put up tough but unsuccessful resistance to
# last year's coup
# Score: 1.0
# Sentence 177:
#
# Worried that party colleagues still face arrest for their politics,
# opposition leader Sam Rainsy sought further clarification Friday of
# security guarantees promised by strongman Hun Sen
# Score: 0.9285714285714286
# Sentence 178: Sam Rainsy wrote
# in a letter to King Norodom Sihanouk that he was eager to attend the
# first session of the new National Assembly on Nov
# Score: 1.0
# Sentence 179: 25, but complained
# that Hun Sen's assurances were not strong enough to ease concerns
# his party members may be arrested upon their return to Cambodia
# Score: 0.9166666666666666
# Sentence 180: Hun
# Sen announced a government guarantee Wednesday of all politicians'
# safety and their right to conduct political activities ``in accordance
# with the laws in force.'' Sam Rainsy, who earlier called Hun Sen's
# statement ``full of loopholes,'' asked Sihanouk for his help in obtaining
# a promise from Hun Sen that all members of the Sam Rainsy Party were
# free from prosecution for their political activities during and after
# last July's election
# Score: 0.9333333333333333
# Sentence 181: Sam Rainsy, a staunch critic of Hun Sen, was
# forced to take refuge in a U.N
# Score: 0.9166666666666666
# Sentence 182: office in September to avoid arrest
# after Hun Sen accused him of being behind a plot against his life
# Score: 1.0
# Sentence 183:
# The alleged assassination attempt came during massive street demonstrations
# organized by the opposition after Hun Sen's Cambodian People's Party
# narrowly won the election
# Score: 1.0
# Sentence 184: The opposition, alleging widespread fraud
# and intimidation, refused to accept the results of the polls
# Score: 1.0
# Sentence 185: Fearing
# for their safety, Sam Rainsy and his then-ally Prince Norodom Ranariddh
# led an exodus of opposition lawmakers out of Cambodia after parliament
# was ceremonially opened in late September
# Score: 0.8888888888888888
# Sentence 186: Ranariddh, whose FUNCINPEC
# party finished a close second in the election, returned last week
# and struck a deal with Hun Sen to form a coalition government
# Score: 1.0
# Sentence 187: The
# agreement will make Hun Sen prime minister and Ranariddh president
# of the National Assembly
# Score: 1.0
# Sentence 188: The two parties have formed three working
# groups to hammer out details of the agreement, including the establishment
# of a Senate to be the upper house of parliament
# Score: 0.9285714285714286
# Sentence 189: Sok An, representing
# Hun Sen's party, said Friday that one working group had completed
# its work on a joint political platform to be implemented by the new
# government
# Score: 1.0
# Sentence 190: The platform is said to emphasize administrative, economic
# and judicial reforms, but Sok An would not reveal details, saying
# Hun Sen would announce it when he presents his Cabinet choices to
# the National Assembly
# Score: 0.9230769230769231
# Sentence 191:
#
# King Norodom Sihanouk on Tuesday praised agreements by Cambodia's
# top two political parties _ previously bitter rivals _ to form a coalition
# government led by strongman Hun Sen
# Score: 0.8333333333333334
# Sentence 192: In a short letter sent to news
# agencies, the king said he had received copies of cooperation agreements
# signed Monday that will place Hun Sen and his Cambodian People's Party
# in firm control of fiscal and administrative functions in the government
# Score: 1.0
# Sentence 193:
# ``The protocol on cooperation between the CPP and FUNCINPEC will certainly
# bring peace and progress to our nation and people,'' Sihanouk wrote
# Score: 1.0
# Sentence 194:
# Uncompromising enemies just a few months ago, Hun Sen and FUNCINPEC
# President Prince Norodom Ranariddh agreed Nov
# Score: 1.0
# Sentence 195: 13 to form a government
# at a summit convened by Sihanouk
# Score: 1.0
# Sentence 196: The deal, which will make Hun Sen
# prime minister and Ranariddh president of the National Assembly, ended
# more than three months of political deadlock that followed a July
# election narrowly won by Hun Sen
# Score: 0.9375
# Sentence 197: Key to the agreement was the formation
# of a Senate as the upper house of Parliament, to be led by CPP President
# Chea Sim, the outgoing head of the National Assembly
# Score: 1.0
# Sentence 198: Sihanouk, recalling
# procedures used in a past government, suggested Tuesday that he should
# appoint the first two members of the upper house
# Score: 0.9090909090909091
# Sentence 199: The remaining senators,
# he said, should be selected by a method agreed upon by the new government
# and the National Assembly
# Score: 1.0
# Sentence 200: Hun Sen said Monday that the CPP and FUNCINPEC
# had agreed that the Senate would be half as large as the 122-seat
# National Assembly
# Score: 1.0
# Sentence 201: Other details of the Senate, including how much
# power it will be given in the promulgation of legislation, have yet
# to be ironed out by the two parties
# Score: 1.0
# Sentence 202:
# cambodian leader hun sen friday reject opposition party demand talk country accuse internationalize political crisisgovernment opposition party ask king norodom sihanouk host summit meeting series post - election negotiation opposition group hun sens party form government failopposition leader prince norodom ranariddh sam rainsy cite hun sen threat arrest opposition figure allege attempt life negotiate freely cambodia call talk sihanouks residence beijinghun sen rejectmake clear meeting relate cambodian affair conduct kingdom cambodiahun sen tell reporter cabinet meeting fridayno - one internationalize cambodian affairdetrimental sovereignty cambodiahun sen cambodian people party win 64 122 parliamentary seat julys election short two - third majority need form governmentranariddh sam rainsy charge hun sen victory election achieve widespread frauddemand investigation election complaint precondition cooperation national assembly move government formhun sen friday opposition concern safety country excuse stay abroadranariddh sam rainsy country parliament ceremonially open sep 24sam rainsy number opposition figure court investigation grenade attack hun sens phnom penh residence sep 7hun sen home time attack police crackdown demonstrator contest hun sen election victorysam rainsy party statement release friday accuse hun sen unwilling make compromise negotiation break deadlockmeet cambodia suggest opposition place party equal foot statementrule party refuse negotiate threaten negotiate partner arrest badking norodom sihanouk decline request chair summit cambodia top political leader meeting bring progress deadlocke negotiation form governmentcambodian leader hun sens rule party two - party opposition call monarch lead top - level talk disagree locationpapa preside summit meeting party hold phnom penh beijing meeting achieve result sihanouk write oct 17 letter son prince norodom ranariddh leader senior opposition funcinpec partycopy letter obtain thursdayking call party make compromise end stalemate papa party responsibility nation peoplehun sen thursdays anniversary peace agreement end countrys civil war pressure opposition form coalition government partyprolong anarchy instability prevent effort set governmenthun sen televise speech mark anniversary 1991 paris peace accordhun sens party win 64 122 seat parliament july national election two - third majority form governmentopposition party lead ranariddh finance minister sam ram rainsy refuse enter coalition hun sen allegation election fraud investigateinternational monitor election free fairhun sen current government remain power long opposition refuse formranariddh sam rainsy remain country sept 24 ceremonial convening parliamentcite hun sen threat arrest opposition politician allege attempt life ranariddh sam rainsy feel safe negotiating inside country ask king chair summit residence beijinghun sen reject opposition reservation inappropriate hold summit countrynegotiation prove fruitless opening parliament sept 22 summit lead kinghun sen imply thursday opposition fail follow promise make summitresult strictly respected reason hold summithun sen speech anniversary 1991 paris peace accordsihanouk reportedly set fly beijing month receive medical treatment chinese doctor75 - year - old monarch suffer variety ailment periodically make extended trip beijingdiagnose colon cancer 1993 remissionseptember thousand people fill street phnom penh protest allege election fraudhun sen order police break demonstrationdemonstrator kill police discovery 20 body aftermath prompt speculation death tally highspeech hun sen blame violence opposition leader demonstration instigate social economic chaoscambodias two - party opposition ask asian development bank monday stop provide loan incumbent government call illegalnegotiation form government deadlocke opposition party leader prince norodom ranariddh sam rainsy country threat arrest strongman hun sen hun sen complain monday opposition make member ret ...
# Score: 0.875
# 202

# %%
import numpy as np
sorted_ix = np.argsort(scores)[::-1]

summary_index=[]
for i in sorted_ix[:summary_size]:
    summary_index.append(i)
print(summary_index)

summary = ""
for i in summary_index:
    summary += sentences[i]       
print(summary)
# Out:
# [100, 200, 107, 106, 105]
# 24Other details of the Senate, including how much
# power it will be given in the promulgation of legislation, have yet
# to be ironed out by the two partiesHun Sen's Cambodian People's Party
# dropped insistence on a joint assembly chairmanship shared by Ranariddh
# and party boss Chea Sim, the current speakerIn a
# long-elusive compromise, opposition leader Prince Norodom Ranariddh
# will become president of the National Assembly resulting from disputed
# elections in July, even though Hun Sen's party holds a majority of
# 64 seats in the 122-member chamber
#
# Cambodia's bickering political parties broke a three-month deadlock
# Friday and agreed to a coalition government leaving strongman Hun
# Sen as sole prime minister, King Norodom Sihanouk announced

# %%
# batch the texts
batch_size = 8
text_batches = [texts[i:i+batch_size] for i in range(0, len(texts), batch_size)]

# generate summaries for each batch
summaries = []
for batch in text_batches:
    input_ids = tokenizer.batch_encode_plus(batch, return_tensors="pt", max_length=512, truncation=True)["input_ids"].to(device)
    summary_ids = model.generate(input_ids, num_beams=4, max_length=20, early_stopping=True)
    batch_summaries = [tokenizer.decode(summary_ids[i], skip_special_tokens=True) for i in range(len(batch))]
    summaries.extend(batch_summaries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 # batch the texts
#       2 batch_size = 8
# ----> 3 text_batches = [texts[i:i+batch_size] for i in range(0, len(texts), batch_size)]
#       5 # generate summaries for each batch
#       6 summaries = []
#
# NameError: name 'texts' is not defined
