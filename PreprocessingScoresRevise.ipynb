# %%
import pandas as pd

# %%
root = "preprocessing/LexRank/our_lexrank_"
frame1 = pd.read_csv(root+"fff_scores_avg.csv")
# frame2 = pd.read_csv(root+"fft_scores_avg.csv")
frame3 = pd.read_csv(root+"ftf_scores_avg.csv")
# frame4 = pd.read_csv(root+"ftt_scores_avg.csv")
frame5 = pd.read_csv(root+"tff_scores_avg.csv")
# frame6 = pd.read_csv(root+"tft_scores_avg.csv")
# frame7 = pd.read_csv(root+"ttf_scores_avg.csv")
frame8 = pd.read_csv(root+"ttt_scores_avg.csv")

# %%
frame1 = frame1.T
frame2 = frame2.T
frame3 = frame3.T
frame4 = frame4.T
frame5 = frame5.T
frame6 = frame6.T
frame7 = frame7.T
frame8 = frame8.T
frame1
# Out:
#                          0                 1               2   \
# Unnamed: 0  rouge1_fmeasure  rouge1_precision   rouge1_recall
# 0            tensor(0.3207)    tensor(0.2569)  tensor(0.4383)
#
#                          3                 4               5   \
# Unnamed: 0  rouge2_fmeasure  rouge2_precision   rouge2_recall
# 0            tensor(0.0723)    tensor(0.0575)  tensor(0.1000)
#
#                          6                 7               8   \
# Unnamed: 0  rougeL_fmeasure  rougeL_precision   rougeL_recall
# 0            tensor(0.1621)    tensor(0.1297)  tensor(0.2220)
#
#                             9                    10                11
# Unnamed: 0  rougeLsum_fmeasure  rougeLsum_precision  rougeLsum_recall
# 0               tensor(0.2671)       tensor(0.2140)    tensor(0.3646)

# %%
frame1["12"] = ["type","fff"]
# frame2["12"] = ["type","fft"]
frame3["12"] = ["type","ftf"]
# frame4["12"] = ["type","ftt"]
frame5["12"] = ["type","tff"]
# frame6["12"] = ["type","tft"]
# frame7["12"] = ["type","ttf"]
frame8["12"] = ["type","ttt"]

# %%
# frame1 = frame1.append(frame2)
frame1 = frame1.append(frame3)
# frame1 = frame1.append(frame4)
frame1 = frame1.append(frame5)
# frame1 = frame1.append(frame6)
# frame1 = frame1.append(frame7)
frame1 = frame1.append(frame8)
# Out:
# C:\Users\Specialist\AppData\Local\Temp\ipykernel_2592\2998463668.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   frame1 = frame1.append(frame3)
# C:\Users\Specialist\AppData\Local\Temp\ipykernel_2592\2998463668.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   frame1 = frame1.append(frame5)
# C:\Users\Specialist\AppData\Local\Temp\ipykernel_2592\2998463668.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   frame1 = frame1.append(frame8)

# %%
frame1 = frame1.rename(columns=frame1.iloc[0]).drop(frame1.index[0])
frame1
# Out:
#   rouge1_fmeasure rouge1_precision   rouge1_recall rouge2_fmeasure  \
# 0  tensor(0.3207)   tensor(0.2569)  tensor(0.4383)  tensor(0.0723)
# 0  tensor(0.3060)   tensor(0.2440)  tensor(0.4223)  tensor(0.0664)
# 0  tensor(0.3364)   tensor(0.3028)  tensor(0.3881)  tensor(0.0769)
# 0  tensor(0.3468)   tensor(0.3101)  tensor(0.4001)  tensor(0.0817)
#
#   rouge2_precision   rouge2_recall rougeL_fmeasure rougeL_precision  \
# 0   tensor(0.0575)  tensor(0.1000)  tensor(0.1621)   tensor(0.1297)
# 0   tensor(0.0524)  tensor(0.0931)  tensor(0.1607)   tensor(0.1280)
# 0   tensor(0.0681)  tensor(0.0902)  tensor(0.1758)   tensor(0.1586)
# 0   tensor(0.0728)  tensor(0.0946)  tensor(0.1763)   tensor(0.1576)
#
#     rougeL_recall rougeLsum_fmeasure rougeLsum_precision rougeLsum_recall type
# 0  tensor(0.2220)     tensor(0.2671)      tensor(0.2140)   tensor(0.3646)  fff
# 0  tensor(0.2223)     tensor(0.2610)      tensor(0.2083)   tensor(0.3597)  ftf
# 0  tensor(0.2026)     tensor(0.2755)      tensor(0.2480)   tensor(0.3179)  tff
# 0  tensor(0.2035)     tensor(0.2868)      tensor(0.2566)   tensor(0.3304)  ttt

# %%
frame1.to_csv(root+'all.csv', index = False, encoding='utf-8')

# %%
from process_dataframe import *
sumdf = pd.read_csv(root+"all.csv")
sumdf = extracted_number_from_df(sumdf)
sumdf
# Out:
#   rouge1_fmeasure rouge1_precision rouge1_recall rouge2_fmeasure  \
# 0          0.3207           0.2569        0.4383          0.0723
# 1           0.306            0.244        0.4223          0.0664
# 2          0.3364           0.3028        0.3881          0.0769
# 3          0.3468           0.3101        0.4001          0.0817
#
#   rouge2_precision rouge2_recall rougeL_fmeasure rougeL_precision  \
# 0           0.0575           0.1          0.1621           0.1297
# 1           0.0524        0.0931          0.1607            0.128
# 2           0.0681        0.0902          0.1758           0.1586
# 3           0.0728        0.0946          0.1763           0.1576
#
#   rougeL_recall rougeLsum_fmeasure rougeLsum_precision rougeLsum_recall type
# 0         0.222             0.2671               0.214           0.3646  fff
# 1        0.2223              0.261              0.2083           0.3597  ftf
# 2        0.2026             0.2755               0.248           0.3179  tff
# 3        0.2035             0.2868              0.2566           0.3304  ttt

# %%
rowssum = []
rowsavg = []
for row in sumdf.iterrows():
    rowssum.append(round(sum(row[1][:-1]), 4))
    rowsavg.append(round(sum(row[1][:-1])/len(row[1][:-1]), 4))

# %%
sumdf["score_sum"] = rowssum
sumdf["score_avg"] = rowsavg
sumdf.to_csv(root+'all.csv', index = False, encoding='utf-8')
