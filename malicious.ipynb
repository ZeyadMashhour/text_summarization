# %%
# Example weights for three models
weights = [0.3, 0.4, 0.3]

# Example summaries generated by the models
summary1 = ['Sentence 1', 'Sentence 2', 'Sentence 3']
summary2 = ['Sentence 2', 'Sentence 4', 'Sentence 5']
summary3 = ['Sentence 1', 'Sentence 2', 'Sentence 5']

# Combine the summaries using the assigned weights
combined_summary = []
for i in range(len(summary1)):
    score = weights[0] * int(summary1[i] in summary2) + weights[1] * int(summary1[i] in summary3) + weights[2] * int(summary2[i] in summary3)
    combined_summary.append((summary1[i], score))
print(combined_summary)

# Choose the top-ranked sentences as the final summary
final_summary = [sentence[0] for sentence in sorted(combined_summary, key=lambda x: x[1], reverse=True)[:3]]

# Normalize the weights to ensure they add up to 1
weights_normalized = [weight/sum(weights) for weight in weights]
# Out:
# [('Sentence 1', 0.7), ('Sentence 2', 0.7), ('Sentence 3', 0.3)]
# [('Sentence 2', 0.6), ('Sentence 4', 0.0), ('Sentence 5', 0.3)]
# [('Sentence 1', 0.3), ('Sentence 2', 0.7), ('Sentence 5', 0.4)]

# %%
weights[0] * int(summary1[i] in summary2)
# Out:
# 0.0

# %%
final_summary
# Out:
# ['Sentence 1', 'Sentence 2', 'Sentence 3']

# %%
combined_summary2 = []
for i in range(len(summary2)):
    score = weights[0] * int(summary2[i] in summary1) + weights[2] * int(summary2[i] in summary3)
    combined_summary2.append((summary2[i], score))
print(combined_summary2)

combined_summary3 = []
for i in range(len(summary1)):
    score = weights[0] * int(summary3[i] in summary1) + weights[1] * int(summary3[i] in summary2)
    combined_summary3.append((summary3[i], score))
print(combined_summary3)

# %%
import pandas as pd
data = pd.read_csv(r'DUC/Duc_first_reference/Scores/DUC_1st_5Sent_lemT_swT_Scores.csv',index_col=0)

# %%
data
# Out:
#                     Original Article Original Summary         ('Tm',)  \
# rouge1_fmeasure       tensor(0.0359)       tensor(1.)  tensor(0.3150)
# rouge1_precision      tensor(0.0184)       tensor(1.)  tensor(0.2518)
# rouge1_recall         tensor(0.8958)       tensor(1.)  tensor(0.4300)
# rouge2_fmeasure       tensor(0.0180)       tensor(1.)  tensor(0.0707)
# rouge2_precision      tensor(0.0092)       tensor(1.)  tensor(0.0563)
# rouge2_recall         tensor(0.4555)       tensor(1.)  tensor(0.0966)
# rougeL_fmeasure       tensor(0.0263)       tensor(1.)  tensor(0.1659)
# rougeL_precision      tensor(0.0135)       tensor(1.)  tensor(0.1326)
# rougeL_recall         tensor(0.6640)       tensor(1.)  tensor(0.2267)
# rougeLsum_fmeasure    tensor(0.0350)       tensor(1.)  tensor(0.2663)
# rougeLsum_precision   tensor(0.0179)       tensor(1.)  tensor(0.2130)
# rougeLsum_recall      tensor(0.8747)       tensor(1.)  tensor(0.3632)
#
#                            ('Lex',)       ('Luhn',)        ('Lsa',)  \
# rouge1_fmeasure      tensor(0.3464)  tensor(0.2699)  tensor(0.2440)
# rouge1_precision     tensor(0.3085)  tensor(0.1984)  tensor(0.2608)
# rouge1_recall        tensor(0.4020)  tensor(0.4326)  tensor(0.2426)
# rouge2_fmeasure      tensor(0.0827)  tensor(0.0516)  tensor(0.0486)
# rouge2_precision     tensor(0.0734)  tensor(0.0380)  tensor(0.0521)
# rouge2_recall        tensor(0.0961)  tensor(0.0819)  tensor(0.0484)
# rougeL_fmeasure      tensor(0.1771)  tensor(0.1365)  tensor(0.1491)
# rougeL_precision     tensor(0.1576)  tensor(0.1003)  tensor(0.1624)
# rougeL_recall        tensor(0.2056)  tensor(0.2189)  tensor(0.1474)
# rougeLsum_fmeasure   tensor(0.2864)  tensor(0.2227)  tensor(0.2194)
# rougeLsum_precision  tensor(0.2551)  tensor(0.1636)  tensor(0.2354)
# rougeLsum_recall     tensor(0.3321)  tensor(0.3569)  tensor(0.2179)
#
#                             ('Tr',)        ('LDA',)   ('Tm', 'Lex')  \
# rouge1_fmeasure      tensor(0.3163)  tensor(0.2653)  tensor(0.3325)
# rouge1_precision     tensor(0.2540)  tensor(0.1956)  tensor(0.2729)
# rouge1_recall        tensor(0.4283)  tensor(0.4213)  tensor(0.4351)
# rouge2_fmeasure      tensor(0.0708)  tensor(0.0518)  tensor(0.0794)
# rouge2_precision     tensor(0.0564)  tensor(0.0382)  tensor(0.0647)
# rouge2_recall        tensor(0.0970)  tensor(0.0820)  tensor(0.1050)
# rougeL_fmeasure      tensor(0.1596)  tensor(0.1402)  tensor(0.1689)
# rougeL_precision     tensor(0.1283)  tensor(0.1036)  tensor(0.1384)
# rougeL_recall        tensor(0.2157)  tensor(0.2215)  tensor(0.2216)
# rougeLsum_fmeasure   tensor(0.2601)  tensor(0.2207)  tensor(0.2792)
# rougeLsum_precision  tensor(0.2089)  tensor(0.1628)  tensor(0.2291)
# rougeLsum_recall     tensor(0.3525)  tensor(0.3504)  tensor(0.3655)
#
#                      ('Tm', 'Luhn')  ... ('Lex', 'Luhn', 'Tr', 'LDA')  \
# rouge1_fmeasure      tensor(0.3058)  ...               tensor(0.3134)
# rouge1_precision     tensor(0.2334)  ...               tensor(0.2418)
# rouge1_recall        tensor(0.4532)  ...               tensor(0.4561)
# rouge2_fmeasure      tensor(0.0692)  ...               tensor(0.0754)
# rouge2_precision     tensor(0.0527)  ...               tensor(0.0577)
# rouge2_recall        tensor(0.1025)  ...               tensor(0.1111)
# rougeL_fmeasure      tensor(0.1573)  ...               tensor(0.1603)
# rougeL_precision     tensor(0.1200)  ...               tensor(0.1233)
# rougeL_recall        tensor(0.2335)  ...               tensor(0.2346)
# rougeLsum_fmeasure   tensor(0.2580)  ...               tensor(0.2608)
# rougeLsum_precision  tensor(0.1969)  ...               tensor(0.2012)
# rougeLsum_recall     tensor(0.3825)  ...               tensor(0.3795)
#
#                     ('Lex', 'Lsa', 'Tr', 'LDA') ('Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                  tensor(0.2997)               tensor(0.2770)
# rouge1_precision                 tensor(0.2723)               tensor(0.2186)
# rouge1_recall                    tensor(0.3431)               tensor(0.3918)
# rouge2_fmeasure                  tensor(0.0676)               tensor(0.0548)
# rouge2_precision                 tensor(0.0623)               tensor(0.0432)
# rouge2_recall                    tensor(0.0766)               tensor(0.0774)
# rougeL_fmeasure                  tensor(0.1665)               tensor(0.1543)
# rougeL_precision                 tensor(0.1515)               tensor(0.1221)
# rougeL_recall                    tensor(0.1903)               tensor(0.2169)
# rougeLsum_fmeasure               tensor(0.2612)               tensor(0.2374)
# rougeLsum_precision              tensor(0.2381)               tensor(0.1876)
# rougeLsum_recall                 tensor(0.2981)               tensor(0.3346)
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')  \
# rouge1_fmeasure                         tensor(0.3131)
# rouge1_precision                        tensor(0.2464)
# rouge1_recall                           tensor(0.4390)
# rouge2_fmeasure                         tensor(0.0747)
# rouge2_precision                        tensor(0.0586)
# rouge2_recall                           tensor(0.1048)
# rougeL_fmeasure                         tensor(0.1676)
# rougeL_precision                        tensor(0.1319)
# rougeL_recall                           tensor(0.2346)
# rougeLsum_fmeasure                      tensor(0.2676)
# rougeLsum_precision                     tensor(0.2106)
# rougeLsum_recall                        tensor(0.3746)
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')  \
# rouge1_fmeasure                          tensor(0.3061)
# rouge1_precision                         tensor(0.2416)
# rouge1_recall                            tensor(0.4269)
# rouge2_fmeasure                          tensor(0.0695)
# rouge2_precision                         tensor(0.0546)
# rouge2_recall                            tensor(0.0973)
# rougeL_fmeasure                          tensor(0.1641)
# rougeL_precision                         tensor(0.1297)
# rougeL_recall                            tensor(0.2285)
# rougeLsum_fmeasure                       tensor(0.2588)
# rougeLsum_precision                      tensor(0.2044)
# rougeLsum_recall                         tensor(0.3605)
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')  \
# rouge1_fmeasure                         tensor(0.3167)
# rouge1_precision                        tensor(0.2463)
# rouge1_recall                           tensor(0.4538)
# rouge2_fmeasure                         tensor(0.0709)
# rouge2_precision                        tensor(0.0548)
# rouge2_recall                           tensor(0.1026)
# rougeL_fmeasure                         tensor(0.1623)
# rougeL_precision                        tensor(0.1262)
# rougeL_recall                           tensor(0.2325)
# rougeLsum_fmeasure                      tensor(0.2636)
# rougeLsum_precision                     tensor(0.2049)
# rougeLsum_recall                        tensor(0.3781)
#
#                     ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                        tensor(0.3210)
# rouge1_precision                       tensor(0.2659)
# rouge1_recall                          tensor(0.4126)
# rouge2_fmeasure                        tensor(0.0718)
# rouge2_precision                       tensor(0.0593)
# rouge2_recall                          tensor(0.0927)
# rougeL_fmeasure                        tensor(0.1699)
# rougeL_precision                       tensor(0.1406)
# rougeL_recall                          tensor(0.2187)
# rougeLsum_fmeasure                     tensor(0.2759)
# rougeLsum_precision                    tensor(0.2287)
# rougeLsum_recall                       tensor(0.3542)
#
#                     ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                         tensor(0.2952)
# rouge1_precision                        tensor(0.2303)
# rouge1_recall                           tensor(0.4229)
# rouge2_fmeasure                         tensor(0.0642)
# rouge2_precision                        tensor(0.0498)
# rouge2_recall                           tensor(0.0922)
# rougeL_fmeasure                         tensor(0.1568)
# rougeL_precision                        tensor(0.1227)
# rougeL_recall                           tensor(0.2235)
# rougeLsum_fmeasure                      tensor(0.2524)
# rougeLsum_precision                     tensor(0.1970)
# rougeLsum_recall                        tensor(0.3615)
#
#                     ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                          tensor(0.3029)
# rouge1_precision                         tensor(0.2407)
# rouge1_recall                            tensor(0.4173)
# rouge2_fmeasure                          tensor(0.0713)
# rouge2_precision                         tensor(0.0563)
# rouge2_recall                            tensor(0.0993)
# rougeL_fmeasure                          tensor(0.1654)
# rougeL_precision                         tensor(0.1315)
# rougeL_recall                            tensor(0.2275)
# rougeLsum_fmeasure                       tensor(0.2592)
# rougeLsum_precision                      tensor(0.2061)
# rougeLsum_recall                         tensor(0.3566)
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                tensor(0.3071)
# rouge1_precision                               tensor(0.2419)
# rouge1_recall                                  tensor(0.4298)
# rouge2_fmeasure                                tensor(0.0704)
# rouge2_precision                               tensor(0.0554)
# rouge2_recall                                  tensor(0.0987)
# rougeL_fmeasure                                tensor(0.1659)
# rougeL_precision                               tensor(0.1309)
# rougeL_recall                                  tensor(0.2313)
# rougeLsum_fmeasure                             tensor(0.2603)
# rougeLsum_precision                            tensor(0.2052)
# rougeLsum_recall                               tensor(0.3641)
#
# [12 rows x 65 columns]

# %%
from process_dataframe import*
import numpy as np

# %%
max_value =  get_max_values(data)
max_value
# Out:
# 0     tensor(0.3507)
# 1     tensor(0.3085)
# 2     tensor(0.4666)
# 3     tensor(0.0892)
# 4     tensor(0.0762)
# 5     tensor(0.1174)
# 6     tensor(0.1809)
# 7     tensor(0.1624)
# 8     tensor(0.2383)
# 9     tensor(0.2912)
# 10    tensor(0.2551)
# 11    tensor(0.3868)
# dtype: object

# %%
data[data.columns[list(np.where(data.loc[data.index[0]] == max_value[0]))[0][0]]]
# Out:
# 0     tensor(0.3507)
# 1     tensor(0.3015)
# 2     tensor(0.4264)
# 3     tensor(0.0892)
# 4     tensor(0.0762)
# 5     tensor(0.1094)
# 6     tensor(0.1809)
# 7     tensor(0.1554)
# 8     tensor(0.2202)
# 9     tensor(0.2912)
# 10    tensor(0.2504)
# 11    tensor(0.3542)
# Name: ('Lex', 'Tr'), dtype: object

# %%
#[0][0] refers to accessing output inside a np array 
data.columns[list(np.where(data.loc[data.index[0]] == max_value[0]))[0][0]]
# Out:
# Index(['('Lex', 'Tr')'], dtype='object')

# %%
def create_dataframe(df, max_values):
    """
    
    """
    output_list = []
    for i in range(len(df.index)):
        output_list.append([df.index[i]
            ,max_values[i]
            ,df.columns[list(np.where(df.loc[df.index[i]] == max_values[i]))[0][0]]])
    columns_names= ["metric", "max_score", "algorithm"]
    output_dataframe = pd.DataFrame(output_list, columns=columns_names)
    return output_dataframe

# %%
create_dataframe(data, max_value)
# Out:
#     metric       max_score              algorithm
# 0        0  tensor(0.3507)          ('Lex', 'Tr')
# 1        1  tensor(0.3085)               ('Lex',)
# 2        2  tensor(0.4666)  ('Lex', 'Luhn', 'Tr')
# 3        3  tensor(0.0892)          ('Lex', 'Tr')
# 4        4  tensor(0.0762)          ('Lex', 'Tr')
# 5        5  tensor(0.1174)  ('Lex', 'Luhn', 'Tr')
# 6        6  tensor(0.1809)          ('Lex', 'Tr')
# 7        7  tensor(0.1624)               ('Lsa',)
# 8        8  tensor(0.2383)        ('Lex', 'Luhn')
# 9        9  tensor(0.2912)          ('Lex', 'Tr')
# 10      10  tensor(0.2551)               ('Lex',)
# 11      11  tensor(0.3868)   ('Tm', 'Luhn', 'Tr')

# %%
max_value = get_max_values(data)
# Out:
# 0     tensor(0.3507)
# 1     tensor(0.3085)
# 2     tensor(0.4666)
# 3     tensor(0.0892)
# 4     tensor(0.0762)
# 5     tensor(0.1174)
# 6     tensor(0.1809)
# 7     tensor(0.1624)
# 8     tensor(0.2383)
# 9     tensor(0.2912)
# 10    tensor(0.2551)
# 11    tensor(0.3868)
# dtype: object

# %%
data1 = extracted_number_from_df(data)
data1
# Out:
#                     Original Article Original Summary ('Tm',) ('Lex',)  \
# rouge1_fmeasure               0.0359              1.0   0.315   0.3464
# rouge1_precision              0.0184              1.0  0.2518   0.3085
# rouge1_recall                 0.8958              1.0    0.43    0.402
# rouge2_fmeasure                0.018              1.0  0.0707   0.0827
# rouge2_precision              0.0092              1.0  0.0563   0.0734
# rouge2_recall                 0.4555              1.0  0.0966   0.0961
# rougeL_fmeasure               0.0263              1.0  0.1659   0.1771
# rougeL_precision              0.0135              1.0  0.1326   0.1576
# rougeL_recall                  0.664              1.0  0.2267   0.2056
# rougeLsum_fmeasure             0.035              1.0  0.2663   0.2864
# rougeLsum_precision           0.0179              1.0   0.213   0.2551
# rougeLsum_recall              0.8747              1.0  0.3632   0.3321
#
#                     ('Luhn',) ('Lsa',) ('Tr',) ('LDA',) ('Tm', 'Lex')  \
# rouge1_fmeasure        0.2699    0.244  0.3163   0.2653        0.3325
# rouge1_precision       0.1984   0.2608   0.254   0.1956        0.2729
# rouge1_recall          0.4326   0.2426  0.4283   0.4213        0.4351
# rouge2_fmeasure        0.0516   0.0486  0.0708   0.0518        0.0794
# rouge2_precision        0.038   0.0521  0.0564   0.0382        0.0647
# rouge2_recall          0.0819   0.0484   0.097    0.082         0.105
# rougeL_fmeasure        0.1365   0.1491  0.1596   0.1402        0.1689
# rougeL_precision       0.1003   0.1624  0.1283   0.1036        0.1384
# rougeL_recall          0.2189   0.1474  0.2157   0.2215        0.2216
# rougeLsum_fmeasure     0.2227   0.2194  0.2601   0.2207        0.2792
# rougeLsum_precision    0.1636   0.2354  0.2089   0.1628        0.2291
# rougeLsum_recall       0.3569   0.2179  0.3525   0.3504        0.3655
#
#                     ('Tm', 'Luhn')  ... ('Lex', 'Luhn', 'Tr', 'LDA')  \
# rouge1_fmeasure             0.3058  ...                       0.3134
# rouge1_precision            0.2334  ...                       0.2418
# rouge1_recall               0.4532  ...                       0.4561
# rouge2_fmeasure             0.0692  ...                       0.0754
# rouge2_precision            0.0527  ...                       0.0577
# rouge2_recall               0.1025  ...                       0.1111
# rougeL_fmeasure             0.1573  ...                       0.1603
# rougeL_precision              0.12  ...                       0.1233
# rougeL_recall               0.2335  ...                       0.2346
# rougeLsum_fmeasure           0.258  ...                       0.2608
# rougeLsum_precision         0.1969  ...                       0.2012
# rougeLsum_recall            0.3825  ...                       0.3795
#
#                     ('Lex', 'Lsa', 'Tr', 'LDA') ('Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                          0.2997                        0.277
# rouge1_precision                         0.2723                       0.2186
# rouge1_recall                            0.3431                       0.3918
# rouge2_fmeasure                          0.0676                       0.0548
# rouge2_precision                         0.0623                       0.0432
# rouge2_recall                            0.0766                       0.0774
# rougeL_fmeasure                          0.1665                       0.1543
# rougeL_precision                         0.1515                       0.1221
# rougeL_recall                            0.1903                       0.2169
# rougeLsum_fmeasure                       0.2612                       0.2374
# rougeLsum_precision                      0.2381                       0.1876
# rougeLsum_recall                         0.2981                       0.3346
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')  \
# rouge1_fmeasure                                 0.3131
# rouge1_precision                                0.2464
# rouge1_recall                                    0.439
# rouge2_fmeasure                                 0.0747
# rouge2_precision                                0.0586
# rouge2_recall                                   0.1048
# rougeL_fmeasure                                 0.1676
# rougeL_precision                                0.1319
# rougeL_recall                                   0.2346
# rougeLsum_fmeasure                              0.2676
# rougeLsum_precision                             0.2106
# rougeLsum_recall                                0.3746
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')  \
# rouge1_fmeasure                                  0.3061
# rouge1_precision                                 0.2416
# rouge1_recall                                    0.4269
# rouge2_fmeasure                                  0.0695
# rouge2_precision                                 0.0546
# rouge2_recall                                    0.0973
# rougeL_fmeasure                                  0.1641
# rougeL_precision                                 0.1297
# rougeL_recall                                    0.2285
# rougeLsum_fmeasure                               0.2588
# rougeLsum_precision                              0.2044
# rougeLsum_recall                                 0.3605
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')  \
# rouge1_fmeasure                                 0.3167
# rouge1_precision                                0.2463
# rouge1_recall                                   0.4538
# rouge2_fmeasure                                 0.0709
# rouge2_precision                                0.0548
# rouge2_recall                                   0.1026
# rougeL_fmeasure                                 0.1623
# rougeL_precision                                0.1262
# rougeL_recall                                   0.2325
# rougeLsum_fmeasure                              0.2636
# rougeLsum_precision                             0.2049
# rougeLsum_recall                                0.3781
#
#                     ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                                 0.321
# rouge1_precision                               0.2659
# rouge1_recall                                  0.4126
# rouge2_fmeasure                                0.0718
# rouge2_precision                               0.0593
# rouge2_recall                                  0.0927
# rougeL_fmeasure                                0.1699
# rougeL_precision                               0.1406
# rougeL_recall                                  0.2187
# rougeLsum_fmeasure                             0.2759
# rougeLsum_precision                            0.2287
# rougeLsum_recall                               0.3542
#
#                     ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                                 0.2952
# rouge1_precision                                0.2303
# rouge1_recall                                   0.4229
# rouge2_fmeasure                                 0.0642
# rouge2_precision                                0.0498
# rouge2_recall                                   0.0922
# rougeL_fmeasure                                 0.1568
# rougeL_precision                                0.1227
# rougeL_recall                                   0.2235
# rougeLsum_fmeasure                              0.2524
# rougeLsum_precision                              0.197
# rougeLsum_recall                                0.3615
#
#                     ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_fmeasure                                  0.3029
# rouge1_precision                                 0.2407
# rouge1_recall                                    0.4173
# rouge2_fmeasure                                  0.0713
# rouge2_precision                                 0.0563
# rouge2_recall                                    0.0993
# rougeL_fmeasure                                  0.1654
# rougeL_precision                                 0.1315
# rougeL_recall                                    0.2275
# rougeLsum_fmeasure                               0.2592
# rougeLsum_precision                              0.2061
# rougeLsum_recall                                 0.3566
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                        0.3071
# rouge1_precision                                       0.2419
# rouge1_recall                                          0.4298
# rouge2_fmeasure                                        0.0704
# rouge2_precision                                       0.0554
# rouge2_recall                                          0.0987
# rougeL_fmeasure                                        0.1659
# rougeL_precision                                       0.1309
# rougeL_recall                                          0.2313
# rougeLsum_fmeasure                                     0.2603
# rougeLsum_precision                                    0.2052
# rougeLsum_recall                                       0.3641
#
# [12 rows x 65 columns]

# %%
df
# Out:
#       Name  Age  Score
# 0    Alice   25     80
# 1      Bob   30     90
# 2  Charlie   35     95
# 3     Dave   40     80
# 4      Eva   45     95

# %%
df.loc[df['Score'] >= 90]
# Out:
#       Name  Age  Score
# 1      Bob   30     90
# 2  Charlie   35     95
# 4      Eva   45     95

# %%
import pandas as pd

# %%
algorithm_df = data[data.columns[:8]]
algorithm_df
# Out:
#                     Original Article Original Summary         ('Tm',)  \
# rouge1_fmeasure       tensor(0.0359)       tensor(1.)  tensor(0.3150)
# rouge1_precision      tensor(0.0184)       tensor(1.)  tensor(0.2518)
# rouge1_recall         tensor(0.8958)       tensor(1.)  tensor(0.4300)
# rouge2_fmeasure       tensor(0.0180)       tensor(1.)  tensor(0.0707)
# rouge2_precision      tensor(0.0092)       tensor(1.)  tensor(0.0563)
# rouge2_recall         tensor(0.4555)       tensor(1.)  tensor(0.0966)
# rougeL_fmeasure       tensor(0.0263)       tensor(1.)  tensor(0.1659)
# rougeL_precision      tensor(0.0135)       tensor(1.)  tensor(0.1326)
# rougeL_recall         tensor(0.6640)       tensor(1.)  tensor(0.2267)
# rougeLsum_fmeasure    tensor(0.0350)       tensor(1.)  tensor(0.2663)
# rougeLsum_precision   tensor(0.0179)       tensor(1.)  tensor(0.2130)
# rougeLsum_recall      tensor(0.8747)       tensor(1.)  tensor(0.3632)
#
#                            ('Lex',)       ('Luhn',)        ('Lsa',)  \
# rouge1_fmeasure      tensor(0.3464)  tensor(0.2699)  tensor(0.2440)
# rouge1_precision     tensor(0.3085)  tensor(0.1984)  tensor(0.2608)
# rouge1_recall        tensor(0.4020)  tensor(0.4326)  tensor(0.2426)
# rouge2_fmeasure      tensor(0.0827)  tensor(0.0516)  tensor(0.0486)
# rouge2_precision     tensor(0.0734)  tensor(0.0380)  tensor(0.0521)
# rouge2_recall        tensor(0.0961)  tensor(0.0819)  tensor(0.0484)
# rougeL_fmeasure      tensor(0.1771)  tensor(0.1365)  tensor(0.1491)
# rougeL_precision     tensor(0.1576)  tensor(0.1003)  tensor(0.1624)
# rougeL_recall        tensor(0.2056)  tensor(0.2189)  tensor(0.1474)
# rougeLsum_fmeasure   tensor(0.2864)  tensor(0.2227)  tensor(0.2194)
# rougeLsum_precision  tensor(0.2551)  tensor(0.1636)  tensor(0.2354)
# rougeLsum_recall     tensor(0.3321)  tensor(0.3569)  tensor(0.2179)
#
#                             ('Tr',)        ('LDA',)
# rouge1_fmeasure      tensor(0.3163)  tensor(0.2653)
# rouge1_precision     tensor(0.2540)  tensor(0.1956)
# rouge1_recall        tensor(0.4283)  tensor(0.4213)
# rouge2_fmeasure      tensor(0.0708)  tensor(0.0518)
# rouge2_precision     tensor(0.0564)  tensor(0.0382)
# rouge2_recall        tensor(0.0970)  tensor(0.0820)
# rougeL_fmeasure      tensor(0.1596)  tensor(0.1402)
# rougeL_precision     tensor(0.1283)  tensor(0.1036)
# rougeL_recall        tensor(0.2157)  tensor(0.2215)
# rougeLsum_fmeasure   tensor(0.2601)  tensor(0.2207)
# rougeLsum_precision  tensor(0.2089)  tensor(0.1628)
# rougeLsum_recall     tensor(0.3525)  tensor(0.3504)

# %%
algorithm_max_values = get_max_values(algorithm_df)

# %%
def create_dataframe(df, max_values):
    """
    This function create dataframe of max_values of each row
    """
    output_list = []
    for i in range(len(df.index)):
        output_list.append([df.index[i]
            ,max_values[i]
            ,df.columns[list(np.where(df.loc[df.index[i]] == max_values[i]))[0][0]]])
            #[0][0] refers to accessing output inside a np array 
    columns_names= ["metric", "max_score", "algorithm"]
    output_dataframe = pd.DataFrame(output_list, columns=columns_names)
    return output_dataframe

# %%
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'Score': [80, 90, 95, 80, 95]
})

# Filter rows based on a certain condition
certain_number = 80
filtered_df = df.loc[df['Score'] >= certain_number]

# Get the maximum value from the filtered rows
max_score = filtered_df['Score'].max()

# Filter rows based on the maximum value
max_scores = filtered_df.loc[filtered_df['Score'] == max_score]

# Print the maximum values
filtered_df
# Out:
#       Name  Age  Score
# 0    Alice   25     80
# 1      Bob   30     90
# 2  Charlie   35     95
# 3     Dave   40     80
# 4      Eva   45     95

# %%
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'Score': [80, 90, 95, 80, 95]
})

# Filter rows based on a certain condition
certain_number = 0.3507
filtered_df = data.loc[data['Original Article'] >= certain_number]

# Get the maximum value from the filtered rows
max_score = filtered_df['Original Article'].max()

# Filter rows based on the maximum value
max_scores = filtered_df.loc[filtered_df['Original Article'] == max_score]

# Print the maximum values
max_scores
# Out:
#               Original Article Original Summary ('Tm',) ('Lex',) ('Luhn',)  \
# rouge1_recall           0.8958              1.0    0.43    0.402    0.4326
#
#               ('Lsa',) ('Tr',) ('LDA',) ('Tm', 'Lex') ('Tm', 'Luhn')  ...  \
# rouge1_recall   0.2426  0.4283   0.4213        0.4351         0.4532  ...
#
#               ('Lex', 'Luhn', 'Tr', 'LDA') ('Lex', 'Lsa', 'Tr', 'LDA')  \
# rouge1_recall                       0.4561                      0.3431
#
#               ('Luhn', 'Lsa', 'Tr', 'LDA') ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')  \
# rouge1_recall                       0.3918                              0.439
#
#               ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')  \
# rouge1_recall                              0.4269
#
#               ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')  \
# rouge1_recall                             0.4538
#
#               ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')  \
# rouge1_recall                            0.4126
#
#               ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_recall                             0.4229
#
#               ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# rouge1_recall                              0.4173
#
#               ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                                    0.4298
#
# [1 rows x 65 columns]

# %%
data.loc[0]
# Out:
# Unnamed: 0                                      1.0
# Original Article                             0.0359
# Original Summary                                1.0
# ('Tm',)                                       0.315
# ('Lex',)                                     0.3464
#                                               ...
# ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')           0.3167
# ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')             0.321
# ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')           0.2952
# ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')          0.3029
# ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')    0.3071
# Name: 0, Length: 66, dtype: object

# %%
filtered_df
# Out:
#       Name  Age  Score
# 1      Bob   30     90
# 2  Charlie   35     95
# 4      Eva   45     95

# %%
ff15
