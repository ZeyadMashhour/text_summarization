# %%
from preprocessing_algorithms import*
from efficiency_scores import*
import pandas as pd
from process_dataframe import*

# %%
third_refrence_path = r"DUC\Duc_third_reference\main_dataset\Duc_dataset_third_ref_summary.csv"
third_refrence_df = pd.read_csv(third_refrence_path)

# %%
ff = pd.read_csv(r'Duc/DUC_1st_5Sent_lemF_swF.csv')
ft = pd.read_csv(r'Duc/DUC_1st_5Sent_lemF_swT.csv')
tf = pd.read_csv(r'Duc/DUC_1st_5Sent_lemT_swF.csv')
tt = pd.read_csv(r'Duc/DUC_1st_5Sent_lemT_swT.csv')

# %%
ffs = get_avg_scores_df(third_refrence_df,ff)
# Out:
# ...
# 100%|██████████| 65/65 [1:06:36<00:00, 61.48s/it]

# %%
fts = get_avg_scores_df(third_refrence_df,ft)
# Out:
# ...
# 100%|██████████| 65/65 [1:05:31<00:00, 60.48s/it]

# %%
tfs = get_avg_scores_df(third_refrence_df,tf)
# Out:
# ...
# 100%|██████████| 65/65 [1:04:51<00:00, 59.87s/it]

# %%
tts = get_avg_scores_df(third_refrence_df,tt)
# Out:
# ...
# 100%|██████████| 65/65 [1:05:03<00:00, 60.05s/it]

# %%
ffs.to_csv('DUC_3st_5Sent_lemF_swF_Scores.csv', index=False, encoding='utf-8')
fts.to_csv('DUC_3st_5Sent_lemF_swT_Scores.csv', index=False, encoding='utf-8') 
tfs.to_csv('DUC_3st_5Sent_lemT_swF_Scores.csv', index=False, encoding='utf-8')
tts.to_csv('DUC_3st_5Sent_lemT_swT_Scores.csv', index=False, encoding='utf-8')
