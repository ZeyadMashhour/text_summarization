# %%
from preprocessing_algorithms import*
from efficiency_scores import*
import pandas as pd
from process_dataframe import*

# %%
fourth_refrence_path = r"DUC\Duc_fourth_reference\main_dataset\Duc_dataset_fourth_ref_summary.csv"
fourth_refrence_df = pd.read_csv(fourth_refrence_path)

# %%
ff = pd.read_csv(r'Duc/DUC_1st_5Sent_lemF_swF.csv')
ft = pd.read_csv(r'Duc/DUC_1st_5Sent_lemF_swT.csv')
tf = pd.read_csv(r'Duc/DUC_1st_5Sent_lemT_swF.csv')
tt = pd.read_csv(r'Duc/DUC_1st_5Sent_lemT_swT.csv')

# %%
ffs = get_avg_scores_df(fourth_refrence_df,ff)
# Out:
# ...
# 100%|██████████| 65/65 [1:06:31<00:00, 61.41s/it]

# %%
fts = get_avg_scores_df(fourth_refrence_df,ft)
# Out:
# ...
# 100%|██████████| 65/65 [1:06:12<00:00, 61.12s/it]

# %%
tfs = get_avg_scores_df(fourth_refrence_df,tf)
# Out:
# ...
#  22%|██▏       | 14/65 [15:03<51:59, 61.17s/it]

# %%
tts = get_avg_scores_df(fourth_refrence_df,tt)
