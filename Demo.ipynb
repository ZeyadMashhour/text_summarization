# %%
import pandas as pd
import os

# %%
first_refrence_path = "Duc_first_reference"
second_refrence_path = "Duc_second_reference"
third_refrence_path = "Duc_third_reference"
fourth_refrence_path = "Duc_fourth_reference"

# %%
def create_directory_list(path):
    return os.listdir(path)

# %%
first_refrence_scores = create_directory_list(first_refrence_path)
second_refrence_scores = create_directory_list(second_refrence_path)
third_refrence_scores = create_directory_list(third_refrence_path)
fourth_refrence_scores = create_directory_list(fourth_refrence_path)

# %%
df = pd.read_csv(f"{first_refrence_path}/{first_refrence_scores[0]}")
df.head(12)
# Out:
#              Unnamed: 0 Original Article Original Summary        ensemble  \
# 0       rouge1_fmeasure   tensor(0.0359)       tensor(1.)  tensor(0.2819)
# 1      rouge1_precision   tensor(0.0184)       tensor(1.)  tensor(0.2105)
# 2         rouge1_recall   tensor(0.8958)       tensor(1.)  tensor(0.4397)
# 3       rouge2_fmeasure   tensor(0.0180)       tensor(1.)  tensor(0.0597)
# 4      rouge2_precision   tensor(0.0092)       tensor(1.)  tensor(0.0444)
# 5         rouge2_recall   tensor(0.4555)       tensor(1.)  tensor(0.0939)
# 6       rougeL_fmeasure   tensor(0.0263)       tensor(1.)  tensor(0.1477)
# 7      rougeL_precision   tensor(0.0135)       tensor(1.)  tensor(0.1105)
# 8         rougeL_recall   tensor(0.6640)       tensor(1.)  tensor(0.2300)
# 9    rougeLsum_fmeasure   tensor(0.0350)       tensor(1.)  tensor(0.2345)
# 10  rougeLsum_precision   tensor(0.0179)       tensor(1.)  tensor(0.1753)
# 11     rougeLsum_recall   tensor(0.8747)       tensor(1.)  tensor(0.3650)
#
#                 tm            luhn             lsa              tr  \
# 0   tensor(0.2664)  tensor(0.2614)  tensor(0.2118)  tensor(0.3003)
# 1   tensor(0.1978)  tensor(0.1883)  tensor(0.2240)  tensor(0.2398)
# 2   tensor(0.4185)  tensor(0.4374)  tensor(0.2152)  tensor(0.4108)
# 3   tensor(0.0574)  tensor(0.0463)  tensor(0.0395)  tensor(0.0517)
# 4   tensor(0.0423)  tensor(0.0333)  tensor(0.0409)  tensor(0.0413)
# 5   tensor(0.0912)  tensor(0.0781)  tensor(0.0410)  tensor(0.0709)
# 6   tensor(0.1427)  tensor(0.1310)  tensor(0.1338)  tensor(0.1478)
# 7   tensor(0.1061)  tensor(0.0943)  tensor(0.1448)  tensor(0.1181)
# 8   tensor(0.2233)  tensor(0.2198)  tensor(0.1340)  tensor(0.2023)
# 9   tensor(0.2249)  tensor(0.2164)  tensor(0.1886)  tensor(0.2496)
# 10  tensor(0.1670)  tensor(0.1558)  tensor(0.2003)  tensor(0.1993)
# 11  tensor(0.3530)  tensor(0.3626)  tensor(0.1913)  tensor(0.3416)
#
#                lex         tm luhn  ...       tm tr lex      luh lsa tr  \
# 0   tensor(0.3062)  tensor(0.2666)  ...  tensor(0.2901)  tensor(0.2616)
# 6   tensor(0.1535)  tensor(0.1486)  tensor(0.1479)  tensor(0.1411)
# 7   tensor(0.1195)  tensor(0.1098)  tensor(0.1105)  tensor(0.1040)
# 8   tensor(0.2212)  tensor(0.2360)  tensor(0.2305)  tensor(0.2264)
# 9   tensor(0.2421)  tensor(0.2387)  tensor(0.2339)  tensor(0.2206)
# 10  tensor(0.1882)  tensor(0.1763)  tensor(0.1746)  tensor(0.1624)
# 11  tensor(0.3493)  tensor(0.3788)  tensor(0.3646)  tensor(0.3546)
#
# [12 rows x 34 columns]

# %%
maxValues = df.iloc[:, 3:].max(axis=1)
type(maxValues)
# Out:
# pandas.core.series.Series

# %%
df.idxmax(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.idxmax(axis=1)
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11021, in DataFrame.idxmax(self, axis, skipna, numeric_only)
#   11018 else:
#   11019     data = self
# > 11021 res = data._reduce(
#   11022     nanops.nanargmax, "argmax", axis=axis, skipna=skipna, numeric_only=False
#   11023 )
#   11024 indices = res._values
#   11026 # indices will always be np.ndarray since axis is not None and
#   11027 # values is a 2d array for DataFrame
#   11028 # error: Item "int" of "Union[int, Any]" has no attribute "__iter__"
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10856, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10852 ignore_failures = numeric_only is None
#   10854 # After possibly _get_data and transposing, we are now in the
#   10855 #  simple case where we can use BlockManager.reduce
# > 10856 res, _ = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#   10857 out = df._constructor(res).iloc[0]
#   10858 if out_dtype is not None:
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1569, in BlockManager.reduce(self, func, ignore_failures)
#    1567 res_blocks: list[Block] = []
#    1568 for blk in self.blocks:
# -> 1569     nbs = blk.reduce(func, ignore_failures)
#    1570     res_blocks.extend(nbs)
#    1572 index = Index([None])  # placeholder
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:136, in maybe_split.<locals>.newfunc(self, *args, **kwargs)
#     133     return meth(self, *args, **kwargs)
#     134 else:
#     135     # Split and operate column-by-column
# --> 136     return self.split_and_operate(meth, *args, **kwargs)
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:432, in Block.split_and_operate(self, func, *args, **kwargs)
#     430 res_blocks = []
#     431 for nb in self._split():
# --> 432     rbs = func(nb, *args, **kwargs)
#     433     res_blocks.extend(rbs)
#     434 return res_blocks
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:2036, in ObjectBlock.reduce(self, func, ignore_failures)
#    2033 assert self.ndim == 2
#    2035 try:
# -> 2036     res = func(self.values)
#    2037 except TypeError:
#    2038     if not ignore_failures:
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10827, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10825     return values._reduce(name, skipna=skipna, **kwds)
#   10826 else:
# > 10827     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\zeyad\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:88, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 if any(self.check(obj) for obj in obj_iter):
#      87     f_name = f.__name__.replace("nan", "")
# ---> 88     raise TypeError(
#      89         f"reduction operation '{f_name}' not allowed for this dtype"
#      90     )
#      91 try:
#      92     with np.errstate(invalid="ignore"):
#
# TypeError: reduction operation 'argmax' not allowed for this dtype
