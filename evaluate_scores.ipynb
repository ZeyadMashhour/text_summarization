# %%
import pandas as pd
#data = pd.read_csv(r'DUC/Duc_first_reference/Scores/DUC_1st_5Sent_lemT_swT_Scores.csv',index_col=0)
data = pd.read_csv(r'BBC_6Sent_Score.csv')
df = pd.read_csv(r"DUC/results\old_scores\DUC_1st_5Sent_lemF_swF_Scores.csv")

# %%
data.head(12)
# Out:
#      ('Tm',)  ('Lex',)  ('Luhn',)  ('Lsa',)   ('Tr',)  ('LDA',)  \
# 0   0.659058  0.652628   0.669293  0.622406  0.516082  0.621183
# 1   0.683257  0.670125   0.652484  0.666458  0.498392  0.666584
# 2   0.684679  0.684860   0.750815  0.621662  0.599783  0.618763
# 3   0.567476  0.554677   0.587951  0.510254  0.390629  0.507476
# 4   0.591280  0.573171   0.575068  0.550968  0.381454  0.549236
# 5   0.587772  0.579489   0.658779  0.506207  0.449979  0.501923
# 6   0.438815  0.430738   0.461122  0.401787  0.337931  0.403296
# 7   0.459585  0.446657   0.453712  0.434942  0.327742  0.437419
# 8   0.452002  0.448441   0.513347  0.397862  0.391602  0.398224
# 9   0.578165  0.562418   0.586444  0.538157  0.438620  0.537839
# 10  0.601354  0.579405   0.573101  0.578235  0.424736  0.579188
# 11  0.599063  0.588619   0.656702  0.535888  0.509028  0.534201
#
#     ('Tm', 'Lex')  ('Tm', 'Luhn')  ('Tm', 'Lsa')  ('Tm', 'Tr')  ...  \
# 0        0.669336        0.689311       0.649642      0.605581  ...
# 1        0.695982        0.702335       0.691026      0.613902  ...
# 2        0.691681        0.731647       0.653715      0.651549  ...
# 3        0.579661        0.612179       0.549688      0.500294  ...
# 4        0.605635        0.625645       0.588073      0.510644  ...
# 5        0.597325        0.648950       0.551000      0.536047  ...
# 6        0.444579        0.472469       0.425800      0.396189  ...
# 7        0.466916        0.486423       0.457513      0.404074  ...
# 8        0.455652        0.497435       0.424922      0.424366  ...
# 9        0.586138        0.610684       0.566455      0.525761  ...
# 10       0.611166        0.623920       0.604701      0.533733  ...
# 11       0.604478        0.646973       0.568342      0.565331  ...
#
#     ('Lex', 'Luhn', 'Tr', 'LDA')  ('Lex', 'Lsa', 'Tr', 'LDA')  \
# 0                       0.648065                     0.616130
# 1                       0.661523                     0.650718
# 2                       0.693635                     0.627035
# 3                       0.558919                     0.504728
# 4                       0.573351                     0.537636
# 5                       0.596519                     0.510343
# 6                       0.434314                     0.400944
# 7                       0.447384                     0.427686
# 8                       0.461303                     0.404622
# 9                       0.564454                     0.530575
# 10                      0.577368                     0.562262
# 11                      0.603496                     0.538479
#
#     ('Luhn', 'Lsa', 'Tr', 'LDA')  ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')  \
# 0                       0.639950                            0.669005
# 1                       0.666815                            0.696373
# 2                       0.663357                            0.691663
# 3                       0.543037                            0.582254
# 4                       0.568523                            0.608617
# 5                       0.561614                            0.600750
# 6                       0.425980                            0.450735
# 7                       0.448903                            0.474019
# 8                       0.437027                            0.461784
# 9                       0.560280                            0.590271
# 10                      0.585877                            0.615821
# 11                      0.579240                            0.609130
#
#     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')  ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')  \
# 0                              0.678301                            0.667657
# 1                              0.715739                            0.689823
# 2                              0.689655                            0.699418
# 3                              0.592252                            0.582156
# 4                              0.627378                            0.603768
# 5                              0.600997                            0.608934
# 6                              0.455458                            0.451490
# 7                              0.486053                            0.471185
# 8                              0.458926                            0.468971
# 9                              0.597643                            0.587136
# 10                             0.632122                            0.607933
# 11                             0.606694                            0.614369
#
#     ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')  ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# 0                            0.641425                            0.658764
# 1                            0.679191                            0.690892
# 2                            0.649574                            0.675625
# 3                            0.539048                            0.567112
# 4                            0.574239                            0.597074
# 5                            0.543911                            0.580648
# 6                            0.420841                            0.440328
# 7                            0.450418                            0.466631
# 8                            0.422278                            0.447642
# 9                            0.558840                            0.580604
# 10                           0.593560                            0.610660
# 11                           0.564527                            0.594030
#
#     ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')  \
# 0                              0.653792
# 1                              0.683625
# 2                              0.674310
# 3                              0.560968
# 4                              0.589377
# 5                              0.577093
# 6                              0.435678
# 7                              0.460844
# 8                              0.444742
# 9                              0.572233
# 10                             0.600200
# 11                             0.588796
#
#     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# 0                                    0.665124
# 1                                    0.698591
# 2                                    0.680897
# 3                                    0.575498
# 4                                    0.607049
# 5                                    0.587868
# 6                                    0.446608
# 7                                    0.474005
# 8                                    0.453180
# 9                                    0.585983
# 10                                   0.617267
# 11                                   0.598419
#
# [12 rows x 63 columns]

# %%
indices = df["Unnamed: 0"]

# %%
data.insert(0, "metrics" ,indices)

# %%
data.to_csv("BBC_6Sent_Score.csv")

# %%
from my_package.df_tools import*
import numpy as np

# %%
max_value =  get_max_values(data)
max_value
# Out:
# 0     0.693038
# 1     0.717925
# 2     0.744136
# 3     0.616789
# 4     0.636266
# 5     0.658383
# 6     0.473779
# 7     0.492200
# 8     0.506177
# 9     0.611992
# 10    0.636630
# 11    0.651078
# dtype: float64

# %%
data[data.columns[list(np.where(data.loc[data.index[0]] == max_value[0]))[0][0]]]
# Out:
# 0     0.693038
# 1     0.710585
# 2     0.730210
# 3     0.616789
# 4     0.634481
# 5     0.648949
# 6     0.473779
# 7     0.490858
# 8     0.495166
# 9     0.611992
# 10    0.629104
# 11    0.643871
# Name: ('Tm', 'Lex', 'Luhn'), dtype: float64

# %%
#[0][0] refers to accessing output inside a np array 
data.columns[list(np.where(data.loc[data.index[0]] == max_value[0]))[0][0]]
# Out:
# "('Tm', 'Lex', 'Luhn')"

# %%
create_max_values_dataframe(data, max_value)
# Out:
#                  metric       max_score              algorithm
# 0       rouge1_fmeasure  tensor(0.3507)          ('Lex', 'Tr')
# 1      rouge1_precision  tensor(0.3085)               ('Lex',)
# 2         rouge1_recall  tensor(0.4666)  ('Lex', 'Luhn', 'Tr')
# 3       rouge2_fmeasure  tensor(0.0892)          ('Lex', 'Tr')
# 4      rouge2_precision  tensor(0.0762)          ('Lex', 'Tr')
# 5         rouge2_recall  tensor(0.1174)  ('Lex', 'Luhn', 'Tr')
# 6       rougeL_fmeasure  tensor(0.1809)          ('Lex', 'Tr')
# 7      rougeL_precision  tensor(0.1624)               ('Lsa',)
# 8         rougeL_recall  tensor(0.2383)        ('Lex', 'Luhn')
# 9    rougeLsum_fmeasure  tensor(0.2912)          ('Lex', 'Tr')
# 10  rougeLsum_precision  tensor(0.2551)               ('Lex',)
# 11     rougeLsum_recall  tensor(0.3868)   ('Tm', 'Luhn', 'Tr')

# %%
max_value = get_max_values(data)

# %%
data1 = extracted_number_from_df(data)
data1
# Out:
#                     Original Article Original Summary ('Tm',) ('Lex',)
# rouge1_fmeasure               0.0359              1.0   0.315   0.3464  \
# rouge1_precision              0.0184              1.0  0.2518   0.3085
# rouge1_recall                 0.8958              1.0    0.43    0.402
# rouge2_fmeasure                0.018              1.0  0.0707   0.0827
# rouge2_precision              0.0092              1.0  0.0563   0.0734
# rouge2_recall                 0.4555              1.0  0.0966   0.0961
# rougeL_fmeasure               0.0263              1.0  0.1659   0.1771
# rougeL_precision              0.0135              1.0  0.1326   0.1576
# rougeL_recall                  0.664              1.0  0.2267   0.2056
# rougeLsum_fmeasure             0.035              1.0  0.2663   0.2864
# rougeLsum_precision           0.0179              1.0   0.213   0.2551
# rougeLsum_recall              0.8747              1.0  0.3632   0.3321
#
#                     ('Luhn',) ('Lsa',) ('Tr',) ('LDA',) ('Tm', 'Lex')
# rouge1_fmeasure        0.2699    0.244  0.3163   0.2653        0.3325  \
# rouge1_precision       0.1984   0.2608   0.254   0.1956        0.2729
# rouge1_recall          0.4326   0.2426  0.4283   0.4213        0.4351
# rouge2_fmeasure        0.0516   0.0486  0.0708   0.0518        0.0794
# rouge2_precision        0.038   0.0521  0.0564   0.0382        0.0647
# rouge2_recall          0.0819   0.0484   0.097    0.082         0.105
# rougeL_fmeasure        0.1365   0.1491  0.1596   0.1402        0.1689
# rougeL_precision       0.1003   0.1624  0.1283   0.1036        0.1384
# rougeL_recall          0.2189   0.1474  0.2157   0.2215        0.2216
# rougeLsum_fmeasure     0.2227   0.2194  0.2601   0.2207        0.2792
# rougeLsum_precision    0.1636   0.2354  0.2089   0.1628        0.2291
# rougeLsum_recall       0.3569   0.2179  0.3525   0.3504        0.3655
#
#                     ('Tm', 'Luhn')  ... ('Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure             0.3058  ...                       0.3134  \
# rouge1_precision            0.2334  ...                       0.2418
# rouge1_recall               0.4532  ...                       0.4561
# rouge2_fmeasure             0.0692  ...                       0.0754
# rouge2_precision            0.0527  ...                       0.0577
# rouge2_recall               0.1025  ...                       0.1111
# rougeL_fmeasure             0.1573  ...                       0.1603
# rougeL_precision              0.12  ...                       0.1233
# rougeL_recall               0.2335  ...                       0.2346
# rougeLsum_fmeasure           0.258  ...                       0.2608
# rougeLsum_precision         0.1969  ...                       0.2012
# rougeLsum_recall            0.3825  ...                       0.3795
#
#                     ('Lex', 'Lsa', 'Tr', 'LDA') ('Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                          0.2997                        0.277  \
# rouge1_precision                         0.2723                       0.2186
# rouge1_recall                            0.3431                       0.3918
# rouge2_fmeasure                          0.0676                       0.0548
# rouge2_precision                         0.0623                       0.0432
# rouge2_recall                            0.0766                       0.0774
# rougeL_fmeasure                          0.1665                       0.1543
# rougeL_precision                         0.1515                       0.1221
# rougeL_recall                            0.1903                       0.2169
# rougeLsum_fmeasure                       0.2612                       0.2374
# rougeLsum_precision                      0.2381                       0.1876
# rougeLsum_recall                         0.2981                       0.3346
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                                 0.3131  \
# rouge1_precision                                0.2464
# rouge1_recall                                    0.439
# rouge2_fmeasure                                 0.0747
# rouge2_precision                                0.0586
# rouge2_recall                                   0.1048
# rougeL_fmeasure                                 0.1676
# rougeL_precision                                0.1319
# rougeL_recall                                   0.2346
# rougeLsum_fmeasure                              0.2676
# rougeLsum_precision                             0.2106
# rougeLsum_recall                                0.3746
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_fmeasure                                  0.3061  \
# rouge1_precision                                 0.2416
# rouge1_recall                                    0.4269
# rouge2_fmeasure                                  0.0695
# rouge2_precision                                 0.0546
# rouge2_recall                                    0.0973
# rougeL_fmeasure                                  0.1641
# rougeL_precision                                 0.1297
# rougeL_recall                                    0.2285
# rougeLsum_fmeasure                               0.2588
# rougeLsum_precision                              0.2044
# rougeLsum_recall                                 0.3605
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.3167  \
# rouge1_precision                                0.2463
# rouge1_recall                                   0.4538
# rouge2_fmeasure                                 0.0709
# rouge2_precision                                0.0548
# rouge2_recall                                   0.1026
# rougeL_fmeasure                                 0.1623
# rougeL_precision                                0.1262
# rougeL_recall                                   0.2325
# rougeLsum_fmeasure                              0.2636
# rougeLsum_precision                             0.2049
# rougeLsum_recall                                0.3781
#
#                     ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.321  \
# rouge1_precision                               0.2659
# rouge1_recall                                  0.4126
# rouge2_fmeasure                                0.0718
# rouge2_precision                               0.0593
# rouge2_recall                                  0.0927
# rougeL_fmeasure                                0.1699
# rougeL_precision                               0.1406
# rougeL_recall                                  0.2187
# rougeLsum_fmeasure                             0.2759
# rougeLsum_precision                            0.2287
# rougeLsum_recall                               0.3542
#
#                     ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.2952  \
# rouge1_precision                                0.2303
# rouge1_recall                                   0.4229
# rouge2_fmeasure                                 0.0642
# rouge2_precision                                0.0498
# rouge2_recall                                   0.0922
# rougeL_fmeasure                                 0.1568
# rougeL_precision                                0.1227
# rougeL_recall                                   0.2235
# rougeLsum_fmeasure                              0.2524
# rougeLsum_precision                              0.197
# rougeLsum_recall                                0.3615
#
#                     ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                  0.3029  \
# rouge1_precision                                 0.2407
# rouge1_recall                                    0.4173
# rouge2_fmeasure                                  0.0713
# rouge2_precision                                 0.0563
# rouge2_recall                                    0.0993
# rougeL_fmeasure                                  0.1654
# rougeL_precision                                 0.1315
# rougeL_recall                                    0.2275
# rougeLsum_fmeasure                               0.2592
# rougeLsum_precision                              0.2061
# rougeLsum_recall                                 0.3566
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                        0.3071
# rouge1_precision                                       0.2419
# rouge1_recall                                          0.4298
# rouge2_fmeasure                                        0.0704
# rouge2_precision                                       0.0554
# rouge2_recall                                          0.0987
# rougeL_fmeasure                                        0.1659
# rougeL_precision                                       0.1309
# rougeL_recall                                          0.2313
# rougeLsum_fmeasure                                     0.2603
# rougeLsum_precision                                    0.2052
# rougeLsum_recall                                       0.3641
#
# [12 rows x 65 columns]

# %%
#df.loc[df['Score'] >= 90]

# %%
import pandas as pd

# %%
algorithm_df = data[data.columns[:8]]
algorithm_df
# Out:
#                     Original Article Original Summary ('Tm',) ('Lex',)
# rouge1_fmeasure               0.0359              1.0   0.315   0.3464  \
# rouge1_precision              0.0184              1.0  0.2518   0.3085
# rouge1_recall                 0.8958              1.0    0.43    0.402
# rouge2_fmeasure                0.018              1.0  0.0707   0.0827
# rouge2_precision              0.0092              1.0  0.0563   0.0734
# rouge2_recall                 0.4555              1.0  0.0966   0.0961
# rougeL_fmeasure               0.0263              1.0  0.1659   0.1771
# rougeL_precision              0.0135              1.0  0.1326   0.1576
# rougeL_recall                  0.664              1.0  0.2267   0.2056
# rougeLsum_fmeasure             0.035              1.0  0.2663   0.2864
# rougeLsum_precision           0.0179              1.0   0.213   0.2551
# rougeLsum_recall              0.8747              1.0  0.3632   0.3321
#
#                     ('Luhn',) ('Lsa',) ('Tr',) ('LDA',)
# rouge1_fmeasure        0.2699    0.244  0.3163   0.2653
# rouge1_precision       0.1984   0.2608   0.254   0.1956
# rouge1_recall          0.4326   0.2426  0.4283   0.4213
# rouge2_fmeasure        0.0516   0.0486  0.0708   0.0518
# rouge2_precision        0.038   0.0521  0.0564   0.0382
# rouge2_recall          0.0819   0.0484   0.097    0.082
# rougeL_fmeasure        0.1365   0.1491  0.1596   0.1402
# rougeL_precision       0.1003   0.1624  0.1283   0.1036
# rougeL_recall          0.2189   0.1474  0.2157   0.2215
# rougeLsum_fmeasure     0.2227   0.2194  0.2601   0.2207
# rougeLsum_precision    0.1636   0.2354  0.2089   0.1628
# rougeLsum_recall       0.3569   0.2179  0.3525   0.3504

# %%
algorithm_max_values = get_max_values(algorithm_df)

# %%
algorithm_max_values
# Out:
# rouge1_fmeasure        0.3464
# rouge1_precision       0.3085
# rouge1_recall          0.4326
# rouge2_fmeasure        0.0827
# rouge2_precision       0.0734
# rouge2_recall           0.097
# rougeL_fmeasure        0.1771
# rougeL_precision       0.1624
# rougeL_recall          0.2215
# rougeLsum_fmeasure     0.2864
# rougeLsum_precision    0.2551
# rougeLsum_recall       0.3569
# dtype: object

# %%
output_list = []
for i in range(len(data.index)):
    output_list.append([data.index[i]
        ,algorithm_max_values[i]
        ,data.columns[list(np.where(data.loc[data.index[i]] >= algorithm_max_values[i]))[0][0]]])
        #[0][0] refers to accessing output inside a np array 
output_dataframe = pd.DataFrame(output_list)

# %%
# algorithm_max_values.index

# %%
weighting_list = []
for i in range(len(data.index)):
    
    # Filter rows based on a certain condition
    threshold = algorithm_max_values[i]
    print(threshold)
    filtered_df = list(data.loc[algorithm_max_values.index[i]] >= threshold)

    # Print the maximum values
    filtered_df

    # Use boolean indexing to return specific columns based on the mask
    selected_columns = data.loc[:, filtered_df]

    # Print the resulting DataFrame
    weighting_list.append(selected_columns.columns)
    print(selected_columns)
# Out:
# 0.3464
#                     Original Summary ('Lex',) ('Lex', 'Tr')
# rouge1_fmeasure                  1.0   0.3464        0.3507
# rouge1_precision                 1.0   0.3085        0.3015
# rouge1_recall                    1.0    0.402        0.4264
# rouge2_fmeasure                  1.0   0.0827        0.0892
# rouge2_precision                 1.0   0.0734        0.0762
# rouge2_recall                    1.0   0.0961        0.1094
# rougeL_fmeasure                  1.0   0.1771        0.1809
# rougeL_precision                 1.0   0.1576        0.1554
# rougeL_recall                    1.0   0.2056        0.2202
# rougeLsum_fmeasure               1.0   0.2864        0.2912
# rougeLsum_precision              1.0   0.2551        0.2504
# rougeLsum_recall                 1.0   0.3321        0.3542
# 0.3085
#                     Original Summary ('Lex',)
# rouge1_fmeasure                  1.0   0.3464
# rouge1_precision                 1.0   0.3085
# rouge1_recall                    1.0    0.402
# rouge2_fmeasure                  1.0   0.0827
# rouge2_precision                 1.0   0.0734
# rouge2_recall                    1.0   0.0961
# rougeL_fmeasure                  1.0   0.1771
# rougeL_precision                 1.0   0.1576
# rougeL_recall                    1.0   0.2056
# rougeLsum_fmeasure               1.0   0.2864
# rougeLsum_precision              1.0   0.2551
# rougeLsum_recall                 1.0   0.3321
# 0.4326
#                     Original Article Original Summary ('Luhn',) ('Tm', 'Lex')
# rouge1_fmeasure               0.0359              1.0    0.2699        0.3325  \
# rouge1_precision              0.0184              1.0    0.1984        0.2729
# rouge1_recall                 0.8958              1.0    0.4326        0.4351
# rouge2_fmeasure                0.018              1.0    0.0516        0.0794
# rouge2_precision              0.0092              1.0     0.038        0.0647
# rouge2_recall                 0.4555              1.0    0.0819         0.105
# rougeL_fmeasure               0.0263              1.0    0.1365        0.1689
# rougeL_precision              0.0135              1.0    0.1003        0.1384
# rougeL_recall                  0.664              1.0    0.2189        0.2216
# rougeLsum_fmeasure             0.035              1.0    0.2227        0.2792
# rougeLsum_precision           0.0179              1.0    0.1636        0.2291
# rougeLsum_recall              0.8747              1.0    0.3569        0.3655
#
#                     ('Tm', 'Luhn') ('Lex', 'Luhn') ('Luhn', 'Tr')
# rouge1_fmeasure             0.3058          0.3249         0.2782  \
# rouge1_precision            0.2334          0.2526         0.2046
# rouge1_recall               0.4532          0.4658         0.4453
# rouge2_fmeasure             0.0692          0.0802         0.0579
# rouge2_precision            0.0527           0.062         0.0428
# rouge2_recall               0.1025          0.1161         0.0917
# rougeL_fmeasure             0.1573          0.1656         0.1414
# rougeL_precision              0.12          0.1284          0.104
# rougeL_recall               0.2335          0.2383         0.2265
# rougeLsum_fmeasure           0.258          0.2682         0.2305
# rougeLsum_precision         0.1969          0.2086         0.1695
# rougeLsum_recall            0.3825          0.3842         0.3694
#
#                     ('Tr', 'LDA') ('Tm', 'Lex', 'Luhn') ('Tm', 'Lex', 'Tr')
# rouge1_fmeasure            0.3105                0.3212              0.3314  \
# rouge1_precision           0.2405                0.2514              0.2697
# rouge1_recall              0.4478                0.4553               0.439
# rouge2_fmeasure            0.0722                0.0738              0.0785
# rouge2_precision           0.0556                0.0574              0.0634
# rouge2_recall              0.1054                0.1058              0.1052
# rougeL_fmeasure            0.1599                0.1636              0.1682
# rougeL_precision           0.1237                0.1279              0.1368
# rougeL_recall              0.2312                0.2325              0.2231
# rougeLsum_fmeasure         0.2586                0.2649              0.2771
# rougeLsum_precision        0.2001                0.2072              0.2253
# rougeLsum_recall           0.3735                0.3762              0.3672
#
#                      ... ('Luhn', 'Tr', 'LDA') ('Tm', 'Lex', 'Luhn', 'Lsa')
# rouge1_fmeasure      ...                0.2721                        0.311  \
# rouge1_precision     ...                0.2005                       0.2449
# rouge1_recall        ...                0.4332                       0.4355
# rouge2_fmeasure      ...                0.0557                       0.0735
# rouge2_precision     ...                 0.041                       0.0577
# rouge2_recall        ...                0.0886                        0.103
# rougeL_fmeasure      ...                0.1413                       0.1691
# rougeL_precision     ...                 0.104                       0.1332
# rougeL_recall        ...                0.2251                       0.2367
# rougeLsum_fmeasure   ...                0.2256                       0.2667
# rougeLsum_precision  ...                0.1661                       0.2102
# rougeLsum_recall     ...                0.3595                        0.373
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr') ('Tm', 'Lex', 'Luhn', 'LDA')
# rouge1_fmeasure                          0.3221                       0.3166  \
# rouge1_precision                         0.2514                       0.2469
# rouge1_recall                            0.4586                       0.4508
# rouge2_fmeasure                          0.0755                       0.0699
# rouge2_precision                         0.0585                       0.0542
# rouge2_recall                            0.1086                       0.1006
# rougeL_fmeasure                          0.1641                       0.1611
# rougeL_precision                         0.1279                       0.1256
# rougeL_recall                            0.2344                       0.2295
# rougeLsum_fmeasure                       0.2674                       0.2636
# rougeLsum_precision                      0.2088                       0.2056
# rougeLsum_recall                          0.381                       0.3756
#
#                     ('Tm', 'Lex', 'Tr', 'LDA') ('Tm', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                         0.3274                      0.3046  \
# rouge1_precision                        0.2656                      0.2368
# rouge1_recall                           0.4363                      0.4383
# rouge2_fmeasure                         0.0781                      0.0702
# rouge2_precision                        0.0628                      0.0547
# rouge2_recall                           0.1055                      0.1004
# rougeL_fmeasure                         0.1684                      0.1624
# rougeL_precision                        0.1366                      0.1264
# rougeL_recall                           0.2243                      0.2331
# rougeLsum_fmeasure                      0.2749                      0.2614
# rougeLsum_precision                     0.2229                      0.2034
# rougeLsum_recall                        0.3664                      0.3756
#
#                     ('Tm', 'Luhn', 'Tr', 'LDA') ('Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                          0.3015                       0.3134  \
# rouge1_precision                         0.2305                       0.2418
# rouge1_recall                            0.4457                       0.4561
# rouge2_fmeasure                           0.069                       0.0754
# rouge2_precision                         0.0527                       0.0577
# rouge2_recall                            0.1017                       0.1111
# rougeL_fmeasure                          0.1551                       0.1603
# rougeL_precision                         0.1185                       0.1233
# rougeL_recall                            0.2297                       0.2346
# rougeLsum_fmeasure                       0.2546                       0.2608
# rougeLsum_precision                      0.1948                       0.2012
# rougeLsum_recall                          0.376                       0.3795
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                                 0.3131  \
# rouge1_precision                                0.2464
# rouge1_recall                                    0.439
# rouge2_fmeasure                                 0.0747
# rouge2_precision                                0.0586
# rouge2_recall                                   0.1048
# rougeL_fmeasure                                 0.1676
# rougeL_precision                                0.1319
# rougeL_recall                                   0.2346
# rougeLsum_fmeasure                              0.2676
# rougeLsum_precision                             0.2106
# rougeLsum_recall                                0.3746
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.3167
# rouge1_precision                                0.2463
# rouge1_recall                                   0.4538
# rouge2_fmeasure                                 0.0709
# rouge2_precision                                0.0548
# rouge2_recall                                   0.1026
# rougeL_fmeasure                                 0.1623
# rougeL_precision                                0.1262
# rougeL_recall                                   0.2325
# rougeLsum_fmeasure                              0.2636
# rougeLsum_precision                             0.2049
# rougeLsum_recall                                0.3781
#
# [12 rows x 24 columns]
# 0.0827
#                     Original Summary ('Lex',) ('Lex', 'Tr') ('Lex', 'LDA')
# rouge1_fmeasure                  1.0   0.3464        0.3507         0.3393  \
# rouge1_precision                 1.0   0.3085        0.3015          0.289
# rouge1_recall                    1.0    0.402        0.4264         0.4167
# rouge2_fmeasure                  1.0   0.0827        0.0892         0.0827
# rouge2_precision                 1.0   0.0734        0.0762         0.0701
# rouge2_recall                    1.0   0.0961        0.1094         0.1022
# rougeL_fmeasure                  1.0   0.1771        0.1809         0.1747
# rougeL_precision                 1.0   0.1576        0.1554         0.1486
# rougeL_recall                    1.0   0.2056        0.2202         0.2149
# rougeLsum_fmeasure               1.0   0.2864        0.2912         0.2811
# rougeLsum_precision              1.0   0.2551        0.2504         0.2394
# rougeLsum_recall                 1.0   0.3321        0.3542         0.3453
#
#                     ('Lex', 'Tr', 'LDA')
# rouge1_fmeasure                   0.3395
# rouge1_precision                  0.2865
# rouge1_recall                     0.4229
# rouge2_fmeasure                    0.083
# rouge2_precision                  0.0697
# rouge2_recall                     0.1043
# rougeL_fmeasure                   0.1756
# rougeL_precision                  0.1481
# rougeL_recall                     0.2188
# rougeLsum_fmeasure                0.2829
# rougeLsum_precision               0.2388
# rougeLsum_recall                  0.3521
# 0.0734
#                     Original Summary ('Lex',) ('Lex', 'Tr')
# rouge1_fmeasure                  1.0   0.3464        0.3507
# rouge1_precision                 1.0   0.3085        0.3015
# rouge1_recall                    1.0    0.402        0.4264
# rouge2_fmeasure                  1.0   0.0827        0.0892
# rouge2_precision                 1.0   0.0734        0.0762
# rouge2_recall                    1.0   0.0961        0.1094
# rougeL_fmeasure                  1.0   0.1771        0.1809
# rougeL_precision                 1.0   0.1576        0.1554
# rougeL_recall                    1.0   0.2056        0.2202
# rougeLsum_fmeasure               1.0   0.2864        0.2912
# rougeLsum_precision              1.0   0.2551        0.2504
# rougeLsum_recall                 1.0   0.3321        0.3542
# 0.097
#                     Original Article Original Summary ('Tr',) ('Tm', 'Lex')
# rouge1_fmeasure               0.0359              1.0  0.3163        0.3325  \
# rouge1_precision              0.0184              1.0   0.254        0.2729
# rouge1_recall                 0.8958              1.0  0.4283        0.4351
# rouge2_fmeasure                0.018              1.0  0.0708        0.0794
# rouge2_precision              0.0092              1.0  0.0564        0.0647
# rouge2_recall                 0.4555              1.0   0.097         0.105
# rougeL_fmeasure               0.0263              1.0  0.1596        0.1689
# rougeL_precision              0.0135              1.0  0.1283        0.1384
# rougeL_recall                  0.664              1.0  0.2157        0.2216
# rougeLsum_fmeasure             0.035              1.0  0.2601        0.2792
# rougeLsum_precision           0.0179              1.0  0.2089        0.2291
# rougeLsum_recall              0.8747              1.0  0.3525        0.3655
#
#                     ('Tm', 'Luhn') ('Tm', 'Tr') ('Lex', 'Luhn') ('Lex', 'Tr')
# rouge1_fmeasure             0.3058       0.3148          0.3249        0.3507  \
# rouge1_precision            0.2334       0.2505          0.2526        0.3015
# rouge1_recall               0.4532       0.4325          0.4658        0.4264
# rouge2_fmeasure             0.0692       0.0717          0.0802        0.0892
# rouge2_precision            0.0527        0.057           0.062        0.0762
# rouge2_recall               0.1025       0.0983          0.1161        0.1094
# rougeL_fmeasure             0.1573       0.1668          0.1656        0.1809
# rougeL_precision              0.12       0.1327          0.1284        0.1554
# rougeL_recall               0.2335       0.2289          0.2383        0.2202
# rougeLsum_fmeasure           0.258       0.2683          0.2682        0.2912
# rougeLsum_precision         0.1969       0.2138          0.2086        0.2504
# rougeLsum_recall            0.3825        0.368          0.3842        0.3542
#
#                     ('Lex', 'LDA') ('Tr', 'LDA')  ...
# rouge1_fmeasure             0.3393        0.3105  ...  \
# rouge1_precision             0.289        0.2405  ...
# rouge1_recall               0.4167        0.4478  ...
# rouge2_fmeasure             0.0827        0.0722  ...
# rouge2_precision            0.0701        0.0556  ...
# rouge2_recall               0.1022        0.1054  ...
# rougeL_fmeasure             0.1747        0.1599  ...
# rougeL_precision            0.1486        0.1237  ...
# rougeL_recall               0.2149        0.2312  ...
# rougeLsum_fmeasure          0.2811        0.2586  ...
# rougeLsum_precision         0.2394        0.2001  ...
# rougeLsum_recall            0.3453        0.3735  ...
#
#                     ('Tm', 'Lex', 'Tr', 'LDA') ('Tm', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                         0.3274                      0.3046  \
# rouge1_precision                        0.2656                      0.2368
# rouge1_recall                           0.4363                      0.4383
# rouge2_fmeasure                         0.0781                      0.0702
# rouge2_precision                        0.0628                      0.0547
# rouge2_recall                           0.1055                      0.1004
# rougeL_fmeasure                         0.1684                      0.1624
# rougeL_precision                        0.1366                      0.1264
# rougeL_recall                           0.2243                      0.2331
# rougeLsum_fmeasure                      0.2749                      0.2614
# rougeLsum_precision                     0.2229                      0.2034
# rougeLsum_recall                        0.3664                      0.3756
#
#                     ('Tm', 'Luhn', 'Tr', 'LDA') ('Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                          0.3015                       0.3125  \
# rouge1_precision                         0.2305                       0.2506
# rouge1_recall                            0.4457                       0.4231
# rouge2_fmeasure                           0.069                       0.0751
# rouge2_precision                         0.0527                         0.06
# rouge2_recall                            0.1017                       0.1023
# rougeL_fmeasure                          0.1551                       0.1662
# rougeL_precision                         0.1185                       0.1333
# rougeL_recall                            0.2297                        0.225
# rougeLsum_fmeasure                       0.2546                       0.2681
# rougeLsum_precision                      0.1948                       0.2153
# rougeLsum_recall                          0.376                       0.3622
#
#                     ('Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                           0.3134  \
# rouge1_precision                          0.2418
# rouge1_recall                             0.4561
# rouge2_fmeasure                           0.0754
# rouge2_precision                          0.0577
# rouge2_recall                             0.1111
# rougeL_fmeasure                           0.1603
# rougeL_precision                          0.1233
# rougeL_recall                             0.2346
# rougeLsum_fmeasure                        0.2608
# rougeLsum_precision                       0.2012
# rougeLsum_recall                          0.3795
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                                 0.3131  \
# rouge1_precision                                0.2464
# rouge1_recall                                    0.439
# rouge2_fmeasure                                 0.0747
# rouge2_precision                                0.0586
# rouge2_recall                                   0.1048
# rougeL_fmeasure                                 0.1676
# rougeL_precision                                0.1319
# rougeL_recall                                   0.2346
# rougeLsum_fmeasure                              0.2676
# rougeLsum_precision                             0.2106
# rougeLsum_recall                                0.3746
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_fmeasure                                  0.3061  \
# rouge1_precision                                 0.2416
# rouge1_recall                                    0.4269
# rouge2_fmeasure                                  0.0695
# rouge2_precision                                 0.0546
# rouge2_recall                                    0.0973
# rougeL_fmeasure                                  0.1641
# rougeL_precision                                 0.1297
# rougeL_recall                                    0.2285
# rougeLsum_fmeasure                               0.2588
# rougeLsum_precision                              0.2044
# rougeLsum_recall                                 0.3605
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.3167  \
# rouge1_precision                                0.2463
# rouge1_recall                                   0.4538
# rouge2_fmeasure                                 0.0709
# rouge2_precision                                0.0548
# rouge2_recall                                   0.1026
# rougeL_fmeasure                                 0.1623
# rougeL_precision                                0.1262
# rougeL_recall                                   0.2325
# rougeLsum_fmeasure                              0.2636
# rougeLsum_precision                             0.2049
# rougeLsum_recall                                0.3781
#
#                     ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                  0.3029  \
# rouge1_precision                                 0.2407
# rouge1_recall                                    0.4173
# rouge2_fmeasure                                  0.0713
# rouge2_precision                                 0.0563
# rouge2_recall                                    0.0993
# rougeL_fmeasure                                  0.1654
# rougeL_precision                                 0.1315
# rougeL_recall                                    0.2275
# rougeLsum_fmeasure                               0.2592
# rougeLsum_precision                              0.2061
# rougeLsum_recall                                 0.3566
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                        0.3071
# rouge1_precision                                       0.2419
# rouge1_recall                                          0.4298
# rouge2_fmeasure                                        0.0704
# rouge2_precision                                       0.0554
# rouge2_recall                                          0.0987
# rougeL_fmeasure                                        0.1659
# rougeL_precision                                       0.1309
# rougeL_recall                                          0.2313
# rougeLsum_fmeasure                                     0.2603
# rougeLsum_precision                                    0.2052
# rougeLsum_recall                                       0.3641
#
# [12 rows x 31 columns]
# 0.1771
#                     Original Summary ('Lex',) ('Lex', 'Tr')
# rouge1_fmeasure                  1.0   0.3464        0.3507
# rouge1_precision                 1.0   0.3085        0.3015
# rouge1_recall                    1.0    0.402        0.4264
# rouge2_fmeasure                  1.0   0.0827        0.0892
# rouge2_precision                 1.0   0.0734        0.0762
# rouge2_recall                    1.0   0.0961        0.1094
# rougeL_fmeasure                  1.0   0.1771        0.1809
# rougeL_precision                 1.0   0.1576        0.1554
# rougeL_recall                    1.0   0.2056        0.2202
# rougeLsum_fmeasure               1.0   0.2864        0.2912
# rougeLsum_precision              1.0   0.2551        0.2504
# rougeLsum_recall                 1.0   0.3321        0.3542
# 0.1624
#                     Original Summary ('Lsa',)
# rouge1_fmeasure                  1.0    0.244
# rouge1_precision                 1.0   0.2608
# rouge1_recall                    1.0   0.2426
# rouge2_fmeasure                  1.0   0.0486
# rouge2_precision                 1.0   0.0521
# rouge2_recall                    1.0   0.0484
# rougeL_fmeasure                  1.0   0.1491
# rougeL_precision                 1.0   0.1624
# rougeL_recall                    1.0   0.1474
# rougeLsum_fmeasure               1.0   0.2194
# rougeLsum_precision              1.0   0.2354
# rougeLsum_recall                 1.0   0.2179
# 0.2215
#                     Original Article Original Summary ('Tm',) ('LDA',)
# rouge1_fmeasure               0.0359              1.0   0.315   0.2653  \
# rouge1_precision              0.0184              1.0  0.2518   0.1956
# rouge1_recall                 0.8958              1.0    0.43   0.4213
# rouge2_fmeasure                0.018              1.0  0.0707   0.0518
# rouge2_precision              0.0092              1.0  0.0563   0.0382
# rouge2_recall                 0.4555              1.0  0.0966    0.082
# rougeL_fmeasure               0.0263              1.0  0.1659   0.1402
# rougeL_precision              0.0135              1.0  0.1326   0.1036
# rougeL_recall                  0.664              1.0  0.2267   0.2215
# rougeLsum_fmeasure             0.035              1.0  0.2663   0.2207
# rougeLsum_precision           0.0179              1.0   0.213   0.1628
# rougeLsum_recall              0.8747              1.0  0.3632   0.3504
#
#                     ('Tm', 'Lex') ('Tm', 'Luhn') ('Tm', 'Tr') ('Tm', 'LDA')
# rouge1_fmeasure            0.3325         0.3058       0.3148        0.3058  \
# rouge1_precision           0.2729         0.2334       0.2505         0.243
# rouge1_recall              0.4351         0.4532       0.4325        0.4218
# rouge2_fmeasure            0.0794         0.0692       0.0717        0.0654
# rouge2_precision           0.0647         0.0527        0.057         0.052
# rouge2_recall               0.105         0.1025       0.0983        0.0899
# rougeL_fmeasure            0.1689         0.1573       0.1668        0.1609
# rougeL_precision           0.1384           0.12       0.1327        0.1279
# rougeL_recall              0.2216         0.2335       0.2289        0.2219
# rougeLsum_fmeasure         0.2792          0.258       0.2683        0.2581
# rougeLsum_precision        0.2291         0.1969       0.2138        0.2053
# rougeLsum_recall           0.3655         0.3825        0.368        0.3556
#
#                     ('Lex', 'Luhn') ('Luhn', 'Tr')  ...
# rouge1_fmeasure              0.3249         0.2782  ...  \
# rouge1_precision             0.2526         0.2046  ...
# rouge1_recall                0.4658         0.4453  ...
# rouge2_fmeasure              0.0802         0.0579  ...
# rouge2_precision              0.062         0.0428  ...
# rouge2_recall                0.1161         0.0917  ...
# rougeL_fmeasure              0.1656         0.1414  ...
# rougeL_precision             0.1284          0.104  ...
# rougeL_recall                0.2383         0.2265  ...
# rougeLsum_fmeasure           0.2682         0.2305  ...
# rougeLsum_precision          0.2086         0.1695  ...
# rougeLsum_recall             0.3842         0.3694  ...
#
#                     ('Tm', 'Luhn', 'Tr', 'LDA') ('Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                          0.3015                       0.3125  \
# rouge1_precision                         0.2305                       0.2506
# rouge1_recall                            0.4457                       0.4231
# rouge2_fmeasure                           0.069                       0.0751
# rouge2_precision                         0.0527                         0.06
# rouge2_recall                            0.1017                       0.1023
# rougeL_fmeasure                          0.1551                       0.1662
# rougeL_precision                         0.1185                       0.1333
# rougeL_recall                            0.2297                        0.225
# rougeLsum_fmeasure                       0.2546                       0.2681
# rougeLsum_precision                      0.1948                       0.2153
# rougeLsum_recall                          0.376                       0.3622
#
#                     ('Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_fmeasure                            0.3007  \
# rouge1_precision                           0.2414
# rouge1_recall                              0.4081
# rouge2_fmeasure                            0.0702
# rouge2_precision                           0.0561
# rouge2_recall                              0.0961
# rougeL_fmeasure                            0.1637
# rougeL_precision                           0.1315
# rougeL_recall                              0.2219
# rougeLsum_fmeasure                         0.2584
# rougeLsum_precision                        0.2076
# rougeLsum_recall                           0.3503
#
#                     ('Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                           0.3134  \
# rouge1_precision                          0.2418
# rouge1_recall                             0.4561
# rouge2_fmeasure                           0.0754
# rouge2_precision                          0.0577
# rouge2_recall                             0.1111
# rougeL_fmeasure                           0.1603
# rougeL_precision                          0.1233
# rougeL_recall                             0.2346
# rougeLsum_fmeasure                        0.2608
# rougeLsum_precision                       0.2012
# rougeLsum_recall                          0.3795
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                                 0.3131  \
# rouge1_precision                                0.2464
# rouge1_recall                                    0.439
# rouge2_fmeasure                                 0.0747
# rouge2_precision                                0.0586
# rouge2_recall                                   0.1048
# rougeL_fmeasure                                 0.1676
# rougeL_precision                                0.1319
# rougeL_recall                                   0.2346
# rougeLsum_fmeasure                              0.2676
# rougeLsum_precision                             0.2106
# rougeLsum_recall                                0.3746
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_fmeasure                                  0.3061  \
# rouge1_precision                                 0.2416
# rouge1_recall                                    0.4269
# rouge2_fmeasure                                  0.0695
# rouge2_precision                                 0.0546
# rouge2_recall                                    0.0973
# rougeL_fmeasure                                  0.1641
# rougeL_precision                                 0.1297
# rougeL_recall                                    0.2285
# rougeLsum_fmeasure                               0.2588
# rougeLsum_precision                              0.2044
# rougeLsum_recall                                 0.3605
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.3167  \
# rouge1_precision                                0.2463
# rouge1_recall                                   0.4538
# rouge2_fmeasure                                 0.0709
# rouge2_precision                                0.0548
# rouge2_recall                                   0.1026
# rougeL_fmeasure                                 0.1623
# rougeL_precision                                0.1262
# rougeL_recall                                   0.2325
# rougeLsum_fmeasure                              0.2636
# rougeLsum_precision                             0.2049
# rougeLsum_recall                                0.3781
#
#                     ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.2952  \
# rouge1_precision                                0.2303
# rouge1_recall                                   0.4229
# rouge2_fmeasure                                 0.0642
# rouge2_precision                                0.0498
# rouge2_recall                                   0.0922
# rougeL_fmeasure                                 0.1568
# rougeL_precision                                0.1227
# rougeL_recall                                   0.2235
# rougeLsum_fmeasure                              0.2524
# rougeLsum_precision                              0.197
# rougeLsum_recall                                0.3615
#
#                     ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                  0.3029  \
# rouge1_precision                                 0.2407
# rouge1_recall                                    0.4173
# rouge2_fmeasure                                  0.0713
# rouge2_precision                                 0.0563
# rouge2_recall                                    0.0993
# rougeL_fmeasure                                  0.1654
# rougeL_precision                                 0.1315
# rougeL_recall                                    0.2275
# rougeLsum_fmeasure                               0.2592
# rougeLsum_precision                              0.2061
# rougeLsum_recall                                 0.3566
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                        0.3071
# rouge1_precision                                       0.2419
# rouge1_recall                                          0.4298
# rouge2_fmeasure                                        0.0704
# rouge2_precision                                       0.0554
# rouge2_recall                                          0.0987
# rougeL_fmeasure                                        0.1659
# rougeL_precision                                       0.1309
# rougeL_recall                                          0.2313
# rougeLsum_fmeasure                                     0.2603
# rougeLsum_precision                                    0.2052
# rougeLsum_recall                                       0.3641
#
# [12 rows x 36 columns]
# 0.2864
#                     Original Summary ('Lex',) ('Lex', 'Tr')
# rouge1_fmeasure                  1.0   0.3464        0.3507
# rouge1_precision                 1.0   0.3085        0.3015
# rouge1_recall                    1.0    0.402        0.4264
# rouge2_fmeasure                  1.0   0.0827        0.0892
# rouge2_precision                 1.0   0.0734        0.0762
# rouge2_recall                    1.0   0.0961        0.1094
# rougeL_fmeasure                  1.0   0.1771        0.1809
# rougeL_precision                 1.0   0.1576        0.1554
# rougeL_recall                    1.0   0.2056        0.2202
# rougeLsum_fmeasure               1.0   0.2864        0.2912
# rougeLsum_precision              1.0   0.2551        0.2504
# rougeLsum_recall                 1.0   0.3321        0.3542
# 0.2551
#                     Original Summary ('Lex',)
# rouge1_fmeasure                  1.0   0.3464
# rouge1_precision                 1.0   0.3085
# rouge1_recall                    1.0    0.402
# rouge2_fmeasure                  1.0   0.0827
# rouge2_precision                 1.0   0.0734
# rouge2_recall                    1.0   0.0961
# rougeL_fmeasure                  1.0   0.1771
# rougeL_precision                 1.0   0.1576
# rougeL_recall                    1.0   0.2056
# rougeLsum_fmeasure               1.0   0.2864
# rougeLsum_precision              1.0   0.2551
# rougeLsum_recall                 1.0   0.3321
# 0.3569
#                     Original Article Original Summary ('Tm',) ('Luhn',)
# rouge1_fmeasure               0.0359              1.0   0.315    0.2699  \
# rouge1_precision              0.0184              1.0  0.2518    0.1984
# rouge1_recall                 0.8958              1.0    0.43    0.4326
# rouge2_fmeasure                0.018              1.0  0.0707    0.0516
# rouge2_precision              0.0092              1.0  0.0563     0.038
# rouge2_recall                 0.4555              1.0  0.0966    0.0819
# rougeL_fmeasure               0.0263              1.0  0.1659    0.1365
# rougeL_precision              0.0135              1.0  0.1326    0.1003
# rougeL_recall                  0.664              1.0  0.2267    0.2189
# rougeLsum_fmeasure             0.035              1.0  0.2663    0.2227
# rougeLsum_precision           0.0179              1.0   0.213    0.1636
# rougeLsum_recall              0.8747              1.0  0.3632    0.3569
#
#                     ('Tm', 'Lex') ('Tm', 'Luhn') ('Tm', 'Tr') ('Lex', 'Luhn')
# rouge1_fmeasure            0.3325         0.3058       0.3148          0.3249  \
# rouge1_precision           0.2729         0.2334       0.2505          0.2526
# rouge1_recall              0.4351         0.4532       0.4325          0.4658
# rouge2_fmeasure            0.0794         0.0692       0.0717          0.0802
# rouge2_precision           0.0647         0.0527        0.057           0.062
# rouge2_recall               0.105         0.1025       0.0983          0.1161
# rougeL_fmeasure            0.1689         0.1573       0.1668          0.1656
# rougeL_precision           0.1384           0.12       0.1327          0.1284
# rougeL_recall              0.2216         0.2335       0.2289          0.2383
# rougeLsum_fmeasure         0.2792          0.258       0.2683          0.2682
# rougeLsum_precision        0.2291         0.1969       0.2138          0.2086
# rougeLsum_recall           0.3655         0.3825        0.368          0.3842
#
#                     ('Luhn', 'Tr') ('Tr', 'LDA')  ...
# rouge1_fmeasure             0.2782        0.3105  ...  \
# rouge1_precision            0.2046        0.2405  ...
# rouge1_recall               0.4453        0.4478  ...
# rouge2_fmeasure             0.0579        0.0722  ...
# rouge2_precision            0.0428        0.0556  ...
# rouge2_recall               0.0917        0.1054  ...
# rougeL_fmeasure             0.1414        0.1599  ...
# rougeL_precision             0.104        0.1237  ...
# rougeL_recall               0.2265        0.2312  ...
# rougeLsum_fmeasure          0.2305        0.2586  ...
# rougeLsum_precision         0.1695        0.2001  ...
# rougeLsum_recall            0.3694        0.3735  ...
#
#                     ('Tm', 'Luhn', 'Lsa', 'Tr') ('Tm', 'Luhn', 'Lsa', 'LDA')
# rouge1_fmeasure                          0.3046                        0.292  \
# rouge1_precision                         0.2368                       0.2284
# rouge1_recall                            0.4383                       0.4176
# rouge2_fmeasure                          0.0702                       0.0629
# rouge2_precision                         0.0547                       0.0489
# rouge2_recall                            0.1004                       0.0902
# rougeL_fmeasure                          0.1624                       0.1562
# rougeL_precision                         0.1264                       0.1226
# rougeL_recall                            0.2331                       0.2224
# rougeLsum_fmeasure                       0.2614                       0.2501
# rougeLsum_precision                      0.2034                       0.1957
# rougeLsum_recall                         0.3756                       0.3576
#
#                     ('Tm', 'Luhn', 'Tr', 'LDA') ('Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                          0.3015                       0.3125  \
# rouge1_precision                         0.2305                       0.2506
# rouge1_recall                            0.4457                       0.4231
# rouge2_fmeasure                           0.069                       0.0751
# rouge2_precision                         0.0527                         0.06
# rouge2_recall                            0.1017                       0.1023
# rougeL_fmeasure                          0.1551                       0.1662
# rougeL_precision                         0.1185                       0.1333
# rougeL_recall                            0.2297                        0.225
# rougeLsum_fmeasure                       0.2546                       0.2681
# rougeLsum_precision                      0.1948                       0.2153
# rougeLsum_recall                          0.376                       0.3622
#
#                     ('Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                           0.3134  \
# rouge1_precision                          0.2418
# rouge1_recall                             0.4561
# rouge2_fmeasure                           0.0754
# rouge2_precision                          0.0577
# rouge2_recall                             0.1111
# rougeL_fmeasure                           0.1603
# rougeL_precision                          0.1233
# rougeL_recall                             0.2346
# rougeLsum_fmeasure                        0.2608
# rougeLsum_precision                       0.2012
# rougeLsum_recall                          0.3795
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_fmeasure                                 0.3131  \
# rouge1_precision                                0.2464
# rouge1_recall                                    0.439
# rouge2_fmeasure                                 0.0747
# rouge2_precision                                0.0586
# rouge2_recall                                   0.1048
# rougeL_fmeasure                                 0.1676
# rougeL_precision                                0.1319
# rougeL_recall                                   0.2346
# rougeLsum_fmeasure                              0.2676
# rougeLsum_precision                             0.2106
# rougeLsum_recall                                0.3746
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_fmeasure                                  0.3061  \
# rouge1_precision                                 0.2416
# rouge1_recall                                    0.4269
# rouge2_fmeasure                                  0.0695
# rouge2_precision                                 0.0546
# rouge2_recall                                    0.0973
# rougeL_fmeasure                                  0.1641
# rougeL_precision                                 0.1297
# rougeL_recall                                    0.2285
# rougeLsum_fmeasure                               0.2588
# rougeLsum_precision                              0.2044
# rougeLsum_recall                                 0.3605
#
#                     ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.3167  \
# rouge1_precision                                0.2463
# rouge1_recall                                   0.4538
# rouge2_fmeasure                                 0.0709
# rouge2_precision                                0.0548
# rouge2_recall                                   0.1026
# rougeL_fmeasure                                 0.1623
# rougeL_precision                                0.1262
# rougeL_recall                                   0.2325
# rougeLsum_fmeasure                              0.2636
# rougeLsum_precision                             0.2049
# rougeLsum_recall                                0.3781
#
#                     ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                 0.2952  \
# rouge1_precision                                0.2303
# rouge1_recall                                   0.4229
# rouge2_fmeasure                                 0.0642
# rouge2_precision                                0.0498
# rouge2_recall                                   0.0922
# rougeL_fmeasure                                 0.1568
# rougeL_precision                                0.1227
# rougeL_recall                                   0.2235
# rougeLsum_fmeasure                              0.2524
# rougeLsum_precision                              0.197
# rougeLsum_recall                                0.3615
#
#                     ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_fmeasure                                        0.3071
# rouge1_precision                                       0.2419
# rouge1_recall                                          0.4298
# rouge2_fmeasure                                        0.0704
# rouge2_precision                                       0.0554
# rouge2_recall                                          0.0987
# rougeL_fmeasure                                        0.1659
# rougeL_precision                                       0.1309
# rougeL_recall                                          0.2313
# rougeLsum_fmeasure                                     0.2603
# rougeLsum_precision                                    0.2052
# rougeLsum_recall                                       0.3641
#
# [12 rows x 34 columns]

# %%
import collections

def create_weights_index(weighting_list):
  words_lists = weighting_list
  # initialize lists
  document_number = 1
  # initialize pos_index
  positional_index = {}
  #intialize position
  position = 1
  #positional_index[term](freq,{doc:[index]})

  for list in words_lists:
    for term in list:
      if term not in positional_index: #if term does not exist
        positional_index[term] = 1/12
      else: #if term exists already
        positional_index[term] +=1/12
  return dict(collections.OrderedDict(sorted(positional_index.items())))

# %%
len(create_weights_index(weighting_list))
# Out:
# 44

# %%
df = pd.DataFrame([create_weights_index(weighting_list)])
df.head()
# Out:
#    ('LDA',)  ('Lex', 'LDA')  ('Lex', 'Luhn')  ('Lex', 'Luhn', 'LDA')
# 0  0.083333        0.166667         0.333333                0.333333  \
#
#    ('Lex', 'Luhn', 'Lsa', 'LDA')  ('Lex', 'Luhn', 'Lsa', 'Tr')
# 0                       0.083333                          0.25  \
#
#    ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')  ('Lex', 'Luhn', 'Tr')
# 0                             0.166667               0.333333  \
#
#    ('Lex', 'Luhn', 'Tr', 'LDA')  ('Lex', 'Tr')  ...
# 0                      0.333333            0.5  ...  \
#
#    ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')  ('Tm', 'Luhn', 'Tr')
# 0                            0.166667              0.333333  \
#
#    ('Tm', 'Luhn', 'Tr', 'LDA')  ('Tm', 'Tr')  ('Tm', 'Tr', 'LDA')   ('Tm',)
# 0                     0.333333          0.25             0.166667  0.166667  \
#
#    ('Tr', 'LDA')   ('Tr',)  Original Article  Original Summary
# 0       0.333333  0.083333          0.333333               1.0
#
# [1 rows x 44 columns]

# %%
# df.T.to_csv("weights_of_alogrithms_and_their_combinations.csv")

# %%
value = data.loc['rouge1_fmeasure', "('Tm',)"]
value
# Out:
# 0.315

# %%
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'Score': [80, 90, 95, 80, 95]
})

# Filter rows based on a certain condition
certain_number = 80
filtered_df = df.loc[df['Score'] >= certain_number]

# Get the maximum value from the filtered rows
max_score = filtered_df['Score'].max()

# Filter rows based on the maximum value
max_scores = filtered_df.loc[filtered_df['Score'] == max_score]

# Print the maximum values
filtered_df
# Out:
#       Name  Age  Score
# 0    Alice   25     80
# 1      Bob   30     90
# 2  Charlie   35     95
# 3     Dave   40     80
# 4      Eva   45     95

# %%
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'Score': [80, 90, 95, 80, 95]
})

# Filter rows based on a certain condition
certain_number = 0.3507
filtered_df = data.loc[data['Original Article'] >= certain_number]

# Get the maximum value from the filtered rows
max_score = filtered_df['Original Article'].max()

# Filter rows based on the maximum value
max_scores = filtered_df.loc[filtered_df['Original Article'] == max_score]

# Print the maximum values
max_scores
# Out:
#               Original Article Original Summary ('Tm',) ('Lex',) ('Luhn',)
# rouge1_recall           0.8958              1.0    0.43    0.402    0.4326  \
#
#               ('Lsa',) ('Tr',) ('LDA',) ('Tm', 'Lex') ('Tm', 'Luhn')  ...
# rouge1_recall   0.2426  0.4283   0.4213        0.4351         0.4532  ...  \
#
#               ('Lex', 'Luhn', 'Tr', 'LDA') ('Lex', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                       0.4561                      0.3431  \
#
#               ('Luhn', 'Lsa', 'Tr', 'LDA') ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_recall                       0.3918                              0.439  \
#
#               ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_recall                              0.4269  \
#
#               ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_recall                             0.4538  \
#
#               ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                            0.4126  \
#
#               ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                             0.4229  \
#
#               ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                              0.4173  \
#
#               ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                                    0.4298
#
# [1 rows x 65 columns]

# %%
filtered_df
# Out:
#                  Original Article Original Summary ('Tm',) ('Lex',) ('Luhn',)
# rouge1_recall              0.8958              1.0    0.43    0.402    0.4326  \
# rouge2_recall              0.4555              1.0  0.0966   0.0961    0.0819
# rougeL_recall               0.664              1.0  0.2267   0.2056    0.2189
# rougeLsum_recall           0.8747              1.0  0.3632   0.3321    0.3569
#
#                  ('Lsa',) ('Tr',) ('LDA',) ('Tm', 'Lex') ('Tm', 'Luhn')  ...
# rouge1_recall      0.2426  0.4283   0.4213        0.4351         0.4532  ...  \
# rouge2_recall      0.0484   0.097    0.082         0.105         0.1025  ...
# rougeL_recall      0.1474  0.2157   0.2215        0.2216         0.2335  ...
# rougeLsum_recall   0.2179  0.3525   0.3504        0.3655         0.3825  ...
#
#                  ('Lex', 'Luhn', 'Tr', 'LDA') ('Lex', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                          0.4561                      0.3431  \
# rouge2_recall                          0.1111                      0.0766
# rougeL_recall                          0.2346                      0.1903
# rougeLsum_recall                       0.3795                      0.2981
#
#                  ('Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                          0.3918  \
# rouge2_recall                          0.0774
# rougeL_recall                          0.2169
# rougeLsum_recall                       0.3346
#
#                  ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr')
# rouge1_recall                                 0.439  \
# rouge2_recall                                0.1048
# rougeL_recall                                0.2346
# rougeLsum_recall                             0.3746
#
#                  ('Tm', 'Lex', 'Luhn', 'Lsa', 'LDA')
# rouge1_recall                                 0.4269  \
# rouge2_recall                                 0.0973
# rougeL_recall                                 0.2285
# rougeLsum_recall                              0.3605
#
#                  ('Tm', 'Lex', 'Luhn', 'Tr', 'LDA')
# rouge1_recall                                0.4538  \
# rouge2_recall                                0.1026
# rougeL_recall                                0.2325
# rougeLsum_recall                             0.3781
#
#                  ('Tm', 'Lex', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                               0.4126  \
# rouge2_recall                               0.0927
# rougeL_recall                               0.2187
# rougeLsum_recall                            0.3542
#
#                  ('Tm', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                                0.4229  \
# rouge2_recall                                0.0922
# rougeL_recall                                0.2235
# rougeLsum_recall                             0.3615
#
#                  ('Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                                 0.4173  \
# rouge2_recall                                 0.0993
# rougeL_recall                                 0.2275
# rougeLsum_recall                              0.3566
#
#                  ('Tm', 'Lex', 'Luhn', 'Lsa', 'Tr', 'LDA')
# rouge1_recall                                       0.4298
# rouge2_recall                                       0.0987
# rougeL_recall                                       0.2313
# rougeLsum_recall                                    0.3641
#
# [4 rows x 65 columns]
