# %%
#from imported_libraries import *
from summarization_algorithm import * 
from preprocessing_algorithms import*
from efficiency_scores import *

# %%
data = pd.read_csv("Duc_dataset_first_ref_summary.csv",index_col=0)
data
# Out:
#                                              Articles  \
# 0   \nCambodian leader Hun Sen on Friday rejected ...
# 1   \nHonduras braced for potential catastrophe Tu...
# 2   \nCuban President Fidel Castro said Sunday he ...
# 3   \nMUNICH, Germany (AP) _ U.S. prosecutors have...
# 4   \nIn a critical ruling for the North American ...
# 5   \nRebels attacked a village in western Uganda ...
# 6   \nIndonesian President B.J. Habibie finds atte...
# 7   \nIsrael's Cabinet announced within hours of a...
# 8   \nBruises on the face of jailed dissident Anwa...
# 9   \nBRUSSELS, Belgium (AP) _ U.S. special envoy ...
# 10  \nFamine-threatened North Korea's harvest will...
# 11  \nOrganizers of December's Asian Games have di...
# 12  \nHours before China was expected to sign a ke...
# 13  \nA week after the White House and congression...
# 14  \nThe outcome of the Microsoft antitrust case ...
# 15  \nWall Street extended a global stock selloff ...
# ...

# %%
docs = pd.read_csv("DUC Summarized Ensemble FIXED.csv",index_col=0)
docs
# Out:
#                                             ensemble  \
# 0  Government and opposition parties have asked \...
# 0  \nHonduras braced for potential catastrophe Tu...
# 0  The Chilean government has protested Pinochet'...
# 0  U.S. authorities charge \nSalim helped finance...
# 0  \nIn a critical ruling for the North American ...
# 0  Majera \nsaid the attackers were believed to b...
# 0  \nIndonesian President B.J. Habibie finds atte...
# 0  Israel radio quoted \nofficials saying the Cab...
# 0  \nBruises on the face of jailed dissident Anwa...
# 0  Holbrooke said he will explain the ``extreme g...
# 0  Famine-threatened North Korea's harvest will b...
# 0  \nOrganizers of December's Asian Games have di...
# 0  Qin \nhoped the harassment would stop after Ch...
# 0  Not only that, but \nCarville went beyond his ...
# 0  The second week of the trial \nended with the ...
# 0  It was getting closer \nto the low of 7,400 th...
# 0  Turkey accuses Syria of harboring \nTurkish Ku...
# ...

# %%
combinations = list(docs.columns)
combinations
# Out:
# ['ensemble',
#  'tm',
#  'luhn',
#  'lsa',
#  'tr',
#  'lex',
#  'tm luhn',
#  'tm lsa',
#  'tm tr',
#  'tm lex',
#  'luhn lsa',
#  'luhn tr',
#  'luhn lex',
#  'lsa tr',
#  'lsa lex',
#  'tr lex',
#  'tm luhn lsa',
#  'tm luhn tr',
#  'tm luhn lex',
#  'tm lsa tr',
#  'tm lsa lex',
#  'tm tr lex',
#  'luh lsa tr',
#  'luhn lsa lex',
#  'luhn tr lex',
#  'lsa tr lex',
#  'luhn lsa tr lex',
#  'tm lsa tr lex',
#  'tm luhn tr lex',
#  'tm luhn lsa lex',
#  'tm luhn lsa tr']

# %%
ensemble = pd.DataFrame(docs["ensemble"])
ensemble.iloc[0,0]
# Out:
# "Government and opposition parties have asked \nKing Norodom Sihanouk to host a summit meeting after a series of post-election \nnegotiations between the two opposition groups and Hun Sen's party \nto form a new government failed.Hun Sen's \nCambodian People's Party won 64 of the 122 parliamentary seats in \nJuly's elections, short of the two-thirds majority needed to form \na government on its own.King Norodom Sihanouk has declined requests to chair a summit of Cambodia's \ntop political leaders, saying the meeting would not bring any progress \nin deadlocked negotiations to form a government.``Papa will not preside over any summit meeting between the three \nparties, whether it is held in Phnom Penh or Beijing, because such \na meeting will certainly achieve no result,'' Sihanouk wrote in an \nOct. 17 letter to his son, Prince Norodom Ranariddh, leader of the \nsenior opposition FUNCINPEC party.In it, the king called on the three parties to make compromises \nto end the stalemate: 
# ...

# %%
ensemble_scores = rouge_scores_df(df=data, algorithm_summary_df=ensemble)
# Out:
# 100%|██████████| 49/49 [01:13<00:00,  1.50s/it]

# %%
def get_combination(combination_name):
    df = pd.DataFrame(docs[combination_name])
    return df

# %%
avg_scores = []
for combination in combinations:
    combination_df = get_combination(combination)#create dataframe
    ensemble_scores = rouge_scores_df(df=data, algorithm_summary_df=combination_df)
    combination_avg = df_avg_by_column(ensemble_scores)
    avg_scores.append(combination_avg)
# Out:
# ...
# 100%|██████████| 49/49 [01:11<00:00,  1.46s/it]

# %%
ensemble_scores.T
# Out:
#                                  0               1               2   \
# rouge1_fmeasure      tensor(0.0981)  tensor(0.1103)  tensor(0.0925)
# rouge1_precision     tensor(0.0523)  tensor(0.0599)  tensor(0.0490)
# rouge1_recall        tensor(0.8000)  tensor(0.6991)  tensor(0.8144)
# rouge2_fmeasure      tensor(0.0357)  tensor(0.0350)  tensor(0.0258)
# rouge2_precision     tensor(0.0190)  tensor(0.0190)  tensor(0.0137)
# rouge2_recall        tensor(0.2936)  tensor(0.2232)  tensor(0.2292)
# rougeL_fmeasure      tensor(0.0613)  tensor(0.0656)  tensor(0.0527)
# rougeL_precision     tensor(0.0327)  tensor(0.0356)  tensor(0.0279)
# rougeL_recall        tensor(0.5000)  tensor(0.4159)  tensor(0.4639)
# rougeLsum_fmeasure   tensor(0.0914)  tensor(0.0964)  tensor(0.0772)
# rougeLsum_precision  tensor(0.0487)  tensor(0.0523)  tensor(0.0409)
# rougeLsum_recall     tensor(0.7455)  tensor(0.6106)  tensor(0.6804)
#
#                                  3               4               5   \
# ...

# %%
avg_scores_df = pd.DataFrame(avg_scores).T
avg_scores_df.columns = combinations

# %%
avg_scores_df
# Out:
#                            ensemble              tm            luhn  \
# rouge1_fmeasure      tensor(0.0635)  tensor(0.0635)  tensor(0.0609)
# rouge1_precision     tensor(0.0337)  tensor(0.0337)  tensor(0.0322)
# rouge1_recall        tensor(0.6234)  tensor(0.6246)  tensor(0.6321)
# rouge2_fmeasure      tensor(0.0187)  tensor(0.0184)  tensor(0.0174)
# rouge2_precision     tensor(0.0099)  tensor(0.0098)  tensor(0.0092)
# rouge2_recall        tensor(0.1873)  tensor(0.1848)  tensor(0.1862)
# rougeL_fmeasure      tensor(0.0428)  tensor(0.0422)  tensor(0.0407)
# rougeL_precision     tensor(0.0227)  tensor(0.0224)  tensor(0.0215)
# rougeL_recall        tensor(0.4246)  tensor(0.4195)  tensor(0.4288)
# rougeLsum_fmeasure   tensor(0.0577)  tensor(0.0574)  tensor(0.0554)
# rougeLsum_precision  tensor(0.0306)  tensor(0.0305)  tensor(0.0293)
# rougeLsum_recall     tensor(0.5672)  tensor(0.5657)  tensor(0.5779)
#
#                                 lsa              tr             lex  \
# ...

# %%
combination_df.iloc[0,0]
# Out:
# "\nHonduras braced for potential catastrophe Tuesday as Hurricane Mitch \nroared through the northwest Caribbean, churning up high waves and \nintense rain that sent coastal residents scurrying for safer ground. \nPresident Carlos Flores Facusse declared a state of maximum alert \nand the Honduran military sent planes to pluck residents from their \nhomes on islands near the coast.Mitch posed no immediate threat to the United States, forecasters \nsaid, but was expected to remain in the northwest Caribbean for five \ndays.The Honduran \npresident closed schools and public offices on the coast Monday and \nordered all air force planes and helicopters to evacuate people from \nthe Islas de la Bahia, a string of small islands off the country's \ncentral coast.The head of the Honduran armed forces, Gen. Mario Hung \nPacheco, said 5,000 soldiers were standing by to help victims of the \nstorm, but he warned the military could not reach everyone.Mexico mobilized troops and \nemergency work
# ...

# %%
avg_scores_df.to_csv("avg_scores_df.csv")

# %%
avg_scores_df.iloc[0,0]<avg_scores_df.iloc[0,1]
# Out:
# tensor(False)

# %%
# def best_score(row):
# Out:
#   Cell In[12], line 2
#
#     ^
# IndentationError: expected an indented block after function definition on line 1
