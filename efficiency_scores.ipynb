# %%
from torchmetrics.text.rouge import ROUGEScore
rouge = ROUGEScore()
from pprint import pprint

# %%
from summarization_algorithm import *

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")
df=df.iloc[:,1:]#remove first column(unnamed col)
df.dropna(inplace=True)
columns_titles = ["original","summary"]
df=df.reindex(columns=columns_titles)
df
# Out:
#                                                original  \
# 0     The Daman and Diu administration on Wednesday ...
# 1     From her special numbers to TV?appearances, Bo...
# 2     The Indira Gandhi Institute of Medical Science...
# 3     Hotels in Mumbai and other Indian cities are t...
# 4     An alleged suspect in a kidnapping case was fo...
# ...                                                 ...
# 4510  Mumbai, Feb 23 (PTI) Fruit juice concentrate m...
# 4511  Former cricketer Sachin Tendulkar was spotted ...
# 4512  Aamir Khan, whose last film Dangal told the st...
# 4513  Maharahstra Power Minister Chandrashekhar Bawa...
# 4514  More than half of the languages spoken by Indi...
#
#                                                 summary
# 0     The Administration of Union Territory Daman an...
# 1     Malaika Arora slammed an Instagram user who tr...
# 2     The Indira Gandhi Institute of Medical Science...
# 3     Hotels in Maharashtra will train their staff t...
# 4     A 32-year-old man on Wednesday was found hangi...
# ...                                                 ...
# 4510  Fruit juice concentrate maker Rasna is eyeing ...
# 4511  Former Indian cricketer Sachin Tendulkar atten...
# 4512  Aamir Khan, while talking about reality shows ...
# 4513  The Maharashtra government has initiated an in...
# 4514  At least 400 languages or more than half langu...
#
# [4396 rows x 2 columns]

# %%
# sentences = tokenization(text)  # Tokenize the text into sentences
# filtered_sentences = []
# for sentence in sentences:
#     sentence = sentence .replace('!','.').replace('?','.').replace('\n',' ')
#     sentence = sentence .replace('.',' ')
#     filtered_sentences.append(sentence)
# filtered_sentences = remove_stop_words(filtered_sentences)

# %%
def calculate_efficiency(predicted_summary,original_summary):
    from torchmetrics.text.rouge import ROUGEScore
    rouge = ROUGEScore()
    from pprint import pprint
    return rouge(predicted_summary, original_summary)

# %%
def summarize_with(df, summary_algorithm,size = 2):
    rows, columns = df.shape
    #rows = 200#uncomment this for runtime speed
    summarized_text = []
    for row in range(rows):
        text = df.iloc[row,0]
        tokenized_text = tokenization(text)#tokenization here
                                  #(filtered_sentences,sentence)
        summary = summary_algorithm(tokenized_text,tokenized_text,size)
        summarized_text.append(summary)
    summary_df = pd.DataFrame (summarized_text, columns = [f'{summary_algorithm.__name__} summary'])
    return summary_df

# %%
luhn = summarize_with(df,luhn_algorithm).reset_index(drop=True)
text_matching = summarize_with(df,text_matching_algorithm).reset_index(drop=True)
#lsa = summarize_with(df,lsa_summarization).reset_index(drop=True)
LexRank = summarize_with(df,LexRank_algorithm).reset_index(drop=True)
# Out:
# C:\Users\basel\summarization_algorithm.py:195: RuntimeWarning: invalid value encountered in double_scalars
#   new_tf_idf[row,col] = tf_idf[row,col]/sent_length[row]

# %%
horizontal_concat_df = pd.concat(
    [
        df.reset_index(drop=True),
        luhn.reset_index(drop=True),
        #lsa.reset_index(drop=True),
        text_matching.reset_index(drop=True),
        LexRank.reset_index(drop=True)
    ],
    axis=1,
)

horizontal_concat_df
# Out:
#                                                original  \
# 0     The Daman and Diu administration on Wednesday ...
# 1     From her special numbers to TV?appearances, Bo...
# 2     The Indira Gandhi Institute of Medical Science...
# 3     Hotels in Mumbai and other Indian cities are t...
# 4     An alleged suspect in a kidnapping case was fo...
# ...                                                 ...
# 4391  Mumbai, Feb 23 (PTI) Fruit juice concentrate m...
# 4392  Former cricketer Sachin Tendulkar was spotted ...
# 4393  Aamir Khan, whose last film Dangal told the st...
# 4394  Maharahstra Power Minister Chandrashekhar Bawa...
# 4395  More than half of the languages spoken by Indi...
#
#                                                 summary  \
# 0     The Administration of Union Territory Daman an...
# 1     Malaika Arora slammed an Instagram user who tr...
# 2     The Indira Gandhi Institute of Medical Science...
# 3     Hotels in Maharashtra will train their staff t...
# 4     A 32-year-old man on Wednesday was found hangi...
# ...                                                 ...
# 4391  Fruit juice concentrate maker Rasna is eyeing ...
# 4392  Former Indian cricketer Sachin Tendulkar atten...
# 4393  Aamir Khan, while talking about reality shows ...
# 4394  The Maharashtra government has initiated an in...
# 4395  At least 400 languages or more than half langu...
#
#                                  luhn_algorithm summary  \
# 0     She refused to be identified.The notice was is...
# 1     @subbu28 #photographer @prasdnaik A post share...
# 2     It had even asked why the question was introdu...
# 3     With rising property prices, some traditional ...
# 4     An alleged suspect in a kidnapping case was fo...
# ...                                                 ...
# 4391  Mumbai, Feb 23 (PTI) Fruit juice concentrate m...
# 4392  "Sachin Tendulkar and Rekha should resign if t...
# 4393  Aamir Khan, whose last film Dangal told the st...
# 4394  Bhosle has received similar bills in the past ...
# 4395  "At least 400 Indian languages are at the risk...
#
#                         text_matching_algorithm summary  \
# 0     She refused to be identified.The notice was is...
# 1     @subbu28 #photographer @prasdnaik A post share...
# 2     It had even asked why the question was introdu...
# 3     With rising property prices, some traditional ...
# 4     said Kumar?s friend, Dharmendra, who dropped h...
# ...                                                 ...
# 4391  Mumbai, Feb 23 (PTI) Fruit juice concentrate m...
# 4392  "Sachin Tendulkar and Rekha should resign if t...
# 4393  Aamir said here when asked about the message t...
# 4394  Bhosle has received similar bills in the past ...
# 4395  "At least 400 Indian languages are at the risk...
#
#                               LexRank_algorithm summary
# 0     The RSS is the ideological parent of the rulin...
# 1     @subbu28 #photographer @prasdnaik A post share...
# 2     mentioned on the form had nothing to do with t...
# 3     With rising property prices, some traditional ...
# 4     An alleged suspect in a kidnapping case was fo...
# ...                                                 ...
# 4391  The company has invested Rs 100 crore so far o...
# 4392  "Sachin Tendulkar and Rekha should resign if t...
# 4393  So it proved to be a challenge for me as an ac...
# 4394  Bhosle has received similar bills in the past ...
# 4395  "At least 400 Indian languages are at the risk...
#
# [4396 rows x 5 columns]

# %%
horizontal_concat_df[horizontal_concat_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [original, summary, luhn_algorithm summary, text_matching_algorithm summary, LexRank_algorithm summary]
# Index: []

# %%
def df_sentences_efficiency(df,summary_df):
    sentences_efficiency = []
    columns, rows = summary_df.shape
    for column in range(columns):
        #print(column)
        predicted_summary = summary_df.iloc[column,0]
        original_summary = df.iloc[column,0]
        efficiency_dict = calculate_efficiency(predicted_summary,original_summary)
        #pd.DataFrame(data, columns=['Name','Age','Hat Color'])
        sentences_efficiency.append(efficiency_dict)
        #print(sentences_efficiency)
            
    dataframe = pd.DataFrame(sentences_efficiency)
    return dataframe

# %%
luhn_with_scores = pd.concat([luhn,df_sentences_efficiency(df,luhn)],axis = 1)
text_matching_with_scores = pd.concat([text_matching,df_sentences_efficiency(df,text_matching)],axis = 1)
#lsa_with_scores = pd.concat([lsa,df_sentences_efficiency(df,lsa)],axis = 1)
LexRank_with_scores = pd.concat([LexRank,df_sentences_efficiency(df,LexRank)],axis = 1)

# %%
luhn_with_scores
# Out:
#                                  luhn_algorithm summary rouge1_fmeasure  \
# 0     She refused to be identified.The notice was is...  tensor(0.5687)
# 1     @subbu28 #photographer @prasdnaik A post share...  tensor(0.3880)
# 2     It had even asked why the question was introdu...  tensor(0.5150)
# 3     With rising property prices, some traditional ...  tensor(0.8400)
# 4     An alleged suspect in a kidnapping case was fo...  tensor(0.3263)
# ...                                                 ...             ...
# 4391  Mumbai, Feb 23 (PTI) Fruit juice concentrate m...  tensor(0.4635)
# 4392  "Sachin Tendulkar and Rekha should resign if t...  tensor(0.8605)
# 4393  Aamir Khan, whose last film Dangal told the st...  tensor(0.2437)
# 4394  Bhosle has received similar bills in the past ...  tensor(0.6646)
# 4395  "At least 400 Indian languages are at the risk...  tensor(0.7589)
#
#      rouge1_precision   rouge1_recall rouge2_fmeasure rouge2_precision  \
# 0          tensor(1.)  tensor(0.3973)  tensor(0.5632)   tensor(0.9932)
# 1          tensor(1.)  tensor(0.2407)  tensor(0.3855)       tensor(1.)
# 2          tensor(1.)  tensor(0.3468)  tensor(0.5086)   tensor(0.9916)
# 3      tensor(0.9974)  tensor(0.7254)  tensor(0.8375)   tensor(0.9949)
# 4          tensor(1.)  tensor(0.1949)  tensor(0.3191)   tensor(0.9868)
# ...               ...             ...             ...              ...
# 4391       tensor(1.)  tensor(0.3017)  tensor(0.4502)   tensor(0.9811)
# 4392       tensor(1.)  tensor(0.7551)  tensor(0.8516)   tensor(0.9909)
# 4393       tensor(1.)  tensor(0.1387)  tensor(0.2392)   tensor(0.9895)
# 4394       tensor(1.)  tensor(0.4977)  tensor(0.6562)   tensor(0.9906)
# 4395       tensor(1.)  tensor(0.6115)  tensor(0.7534)   tensor(0.9941)
#
#        rouge2_recall rougeL_fmeasure rougeL_precision   rougeL_recall  \
# 0     tensor(0.3930)  tensor(0.3588)   tensor(0.6309)  tensor(0.2507)
# 1     tensor(0.2388)  tensor(0.3880)       tensor(1.)  tensor(0.2407)
# 2     tensor(0.3420)  tensor(0.3305)   tensor(0.6417)  tensor(0.2225)
# 3     tensor(0.7230)  tensor(0.7476)   tensor(0.8878)  tensor(0.6456)
# 4     tensor(0.1904)  tensor(0.3263)       tensor(1.)  tensor(0.1949)
# ...              ...             ...              ...             ...
# 4391  tensor(0.2921)  tensor(0.4635)       tensor(1.)  tensor(0.3017)
# 4392  tensor(0.7466)  tensor(0.5194)   tensor(0.6036)  tensor(0.4558)
# 4393  tensor(0.1360)  tensor(0.2437)       tensor(1.)  tensor(0.1387)
# 4394  tensor(0.4907)  tensor(0.3913)   tensor(0.5888)  tensor(0.2930)
# 4395  tensor(0.6065)  tensor(0.4911)   tensor(0.6471)  tensor(0.3957)
#
#      rougeLsum_fmeasure rougeLsum_precision rougeLsum_recall
# 0        tensor(0.5687)          tensor(1.)   tensor(0.3973)
# 1        tensor(0.3880)          tensor(1.)   tensor(0.2407)
# 2        tensor(0.5150)          tensor(1.)   tensor(0.3468)
# 3        tensor(0.8400)      tensor(0.9974)   tensor(0.7254)
# 4        tensor(0.3263)          tensor(1.)   tensor(0.1949)
# ...                 ...                 ...              ...
# 4391     tensor(0.4635)          tensor(1.)   tensor(0.3017)
# 4392     tensor(0.8605)          tensor(1.)   tensor(0.7551)
# 4393     tensor(0.2437)          tensor(1.)   tensor(0.1387)
# 4394     tensor(0.6646)          tensor(1.)   tensor(0.4977)
# 4395     tensor(0.7589)          tensor(1.)   tensor(0.6115)
#
# [4396 rows x 13 columns]

# %%
import spacy
def preprocessing(text):
    sentences = text

    # Load the model (English) into spaCy
    nlp = spacy.load('en_core_web_sm')

    # Adding 'sentencizer' component to the pipeline
    nlp.add_pipe('sentencizer')

    # Tokenization & Lemmatization
    lemmatized_sentences = []

    doc = nlp(sentences)

    sentences = []
    for sentence in doc.sents:
        sentences.append(sentence)
        lemmatized_sentences.append([token.lemma_ for token in sentence])


    # Removing Stop Words & Punctuation 
    filtered_sentences = []

    for sentences_group in lemmatized_sentences:
        filtered = ""

        for sentence in sentences_group:
            sentence_doc = nlp(sentence)
            words_of_sentence = [token.text for token in sentence_doc]

            for token in sentence_doc:
                if token.is_stop == False and token.text.isalpha() == True:
                    filtered += token.text + " "

        filtered_sentences.append(filtered)

    return sentences, filtered_sentences

# %%
text = 'The Daman and Diu administration on Wednesday withdrew a circular that asked women staff to tie rakhis on male colleagues after the order triggered a backlash from employees and was ripped apart on social media.The union territory?s administration was forced to retreat within 24 hours of issuing the circular that made it compulsory for its staff to celebrate Rakshabandhan at workplace.?It has been decided to celebrate the festival of Rakshabandhan on August 7. In this connection, all offices/ departments shall remain open and celebrate the festival collectively at a suitable time wherein all the lady staff shall tie rakhis to their colleagues,? the order, issued on August 1 by Gurpreet Singh, deputy secretary (personnel), had said.To ensure that no one skipped office, an attendance report was to be sent to the government the next evening.The two notifications ? one mandating the celebration of Rakshabandhan (left) and the other withdrawing the mandate (right) ? were issued by the Daman and Diu administration a day apart. The circular was withdrawn through a one-line order issued late in the evening by the UT?s department of personnel and administrative reforms.?The circular is ridiculous. There are sensitivities involved. How can the government dictate who I should tie rakhi to? We should maintain the professionalism of a workplace? an official told Hindustan Times earlier in the day. She refused to be identified.The notice was issued on Daman and Diu administrator and former Gujarat home minister Praful Kodabhai Patel?s direction, sources said.Rakshabandhan, a celebration of the bond between brothers and sisters, is one of several Hindu festivities and rituals that are no longer confined of private, family affairs but have become tools to push politic al ideologies.In 2014, the year BJP stormed to power at the Centre, Rashtriya Swayamsevak Sangh (RSS) chief Mohan Bhagwat said the festival had ?national significance? and should be celebrated widely ?to protect Hindu culture and live by the values enshrined in it?. The RSS is the ideological parent of the ruling BJP.Last year, women ministers in the Modi government went to the border areas to celebrate the festival with soldiers. A year before, all cabinet ministers were asked to go to their constituencies for the festival.'

# %%
sent, fill_sent = preprocessing(text)
print(type(sent))
print(sent)
# Out:
# <class 'list'>
# [The Daman and Diu administration on Wednesday withdrew a circular that asked women staff to tie rakhis on male colleagues after the order triggered a backlash from employees and was ripped apart on social media., The union territory?s administration was forced to retreat within 24 hours of issuing the circular that made it compulsory for its staff to celebrate Rakshabandhan at workplace.?It has been decided to celebrate the festival of Rakshabandhan on August 7., In this connection, all offices/ departments shall remain open and celebrate the festival collectively at a suitable time wherein all the lady staff shall tie rakhis to their colleagues,?, the order, issued on August 1 by Gurpreet Singh, deputy secretary (personnel), had said., To ensure that no one skipped office, an attendance report was to be sent to the government the next evening., The two notifications ?, one mandating the celebration of Rakshabandhan (left) and the other withdrawing the mandate (right) ?, were issued by the Daman and Diu administration a day apart., The circular was withdrawn through a one-line order issued late in the evening by the UT?s department of personnel and administrative reforms.?The circular is ridiculous., There are sensitivities involved., How can the government dictate who I should tie rakhi to?, We should maintain the professionalism of a workplace?, an official told Hindustan Times earlier in the day., She refused to be identified., The notice was issued on Daman and Diu administrator and former Gujarat home minister Praful Kodabhai Patel?s direction, sources said., Rakshabandhan, a celebration of the bond between brothers and sisters, is one of several Hindu festivities and rituals that are no longer confined of private, family affairs but have become tools to push politic al ideologies., In 2014, the year BJP stormed to power at the Centre, Rashtriya Swayamsevak Sangh (RSS) chief Mohan Bhagwat said the festival had ?national significance?, and should be celebrated widely ?, to protect Hindu culture and live by the values enshrined in it?., The RSS is the ideological parent of the ruling BJP.Last year, women ministers in the Modi government went to the border areas to celebrate the festival with soldiers., A year before, all cabinet ministers were asked to go to their constituencies for the festival.]
