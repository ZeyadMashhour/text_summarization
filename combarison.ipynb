# %%
import glob
import pandas as pd

path = r"C:\Users\basel\OneDrive\Desktop\GP_Project\text_summarization\weighted_scores\*.csv" # Replace with the actual path to your CSV files
all_weighted_files = glob.glob(path)

dfws = [] # Empty list to store all the DataFrames
weighted_names = []

for file in all_weighted_files:
    wdf = pd.read_csv(file,index_col=0)
    weighted_names.append(file)
    dfws.append(wdf)

# %%
import glob
import pandas as pd

path = r"C:\Users\basel\OneDrive\Desktop\GP_Project\text_summarization\DUC\Scores\*.csv" # Replace with the actual path to your CSV files
all_files = glob.glob(path)

dfs = [] # Empty list to store all the DataFrames
names = []

for file in all_files:
    df = pd.read_csv(file,index_col=0)
    names.append(file)
    dfs.append(df)

# %%
print(weighted_names)
dfws[0]
# Out:
# ['C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_1st_5Sent_lemF_swF_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_1st_5Sent_lemF_swT_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_1st_5Sent_lemT_swF_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_1st_5Sent_lemT_swT_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_2st_5Sent_lemF_swF_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_2st_5Sent_lemF_swT_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\weighted_scores\\DUC_2st_5Sent_lemT_swF_Weighted_Scores.csv', 'C:\\Users\\basel\\OneDrive\\Desktop\\GP_Project\\text_summarization\\wei
# ...

# %%
print(names[0])
dfs[0]
# Out:
# C:\Users\basel\OneDrive\Desktop\GP_Project\text_summarization\DUC\Scores\DUC_1st_5Sent_lemF_swF_Scores.csv
#                     Original Article Original Summary         ('Tm',)
# rouge1_fmeasure       tensor(0.0359)       tensor(1.)  tensor(0.2732)  \
# rouge1_precision      tensor(0.0184)       tensor(1.)  tensor(0.2036)
# rouge1_recall         tensor(0.8958)       tensor(1.)  tensor(0.4247)
# rouge2_fmeasure       tensor(0.0180)       tensor(1.)  tensor(0.0581)
# rouge2_precision      tensor(0.0092)       tensor(1.)  tensor(0.0431)
# rouge2_recall         tensor(0.4555)       tensor(1.)  tensor(0.0910)
# rougeL_fmeasure       tensor(0.0263)       tensor(1.)  tensor(0.1459)
# rougeL_precision      tensor(0.0135)       tensor(1.)  tensor(0.1089)
# rougeL_recall         tensor(0.6640)       tensor(1.)  tensor(0.2258)
# rougeLsum_fmeasure    tensor(0.0350)       tensor(1.)  tensor(0.2275)
# rougeLsum_precision   tensor(0.0179)       tensor(1.)  tensor(0.1696)
# ...
