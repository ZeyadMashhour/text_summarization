# %%
from preprocessing_algorithms import*

# %%
from efficiency_scores import*

# %%
first_refrence_path = r"DUC\main_dataset\Duc_dataset_first_ref_summary.csv"
second_refrence_path = r"DUC\main_dataset\Duc_dataset_second_ref_summary.csv"
third_refrence_path = r"DUC\main_dataset\Duc_dataset_third_ref_summary.csv"
fourth_refrence_path = r"DUC\main_dataset\Duc_dataset_fourth_ref_summary.csv"

# %%
first_refrence_df = pd.read_csv(first_refrence_path)
second_refrence_df = pd.read_csv(second_refrence_path)
third_refrence_df = pd.read_csv(third_refrence_path)
fourth_refrence_df = pd.read_csv(fourth_refrence_path)
original_article = first_refrence_df["Original Article"]

# %%
import pandas as pd

# %%
from process_dataframe import*

# %%
# ff = pd.read_csv(r'Duc/DUC_1st_5Sent_lemF_swF.csv')
# ft = pd.read_csv(r'Duc/DUC_1st_5Sent_lemF_swT.csv')
# tf = pd.read_csv(r'Duc/DUC_1st_5Sent_lemT_swF.csv')
# tt = pd.read_csv(r'Duc/DUC_1st_5Sent_lemT_swT.csv')

# %%
ffs1 = pd.read_csv(r'DUC/Scores_length_5/DUC_1st_5Sent_lemF_swF_Scores.csv', index_col=0)
fts1 = pd.read_csv(r'DUC/Scores_length_5/DUC_1st_5Sent_lemF_swT_Scores.csv', index_col=0)
tfs1 = pd.read_csv(r'DUC/Scores_length_5/DUC_1st_5Sent_lemT_swF_Scores.csv', index_col=0)
tts1 = pd.read_csv(r'DUC/Scores_length_5/DUC_1st_5Sent_lemT_swT_Scores.csv', index_col=0)

# %%
ffs2 = pd.read_csv(r'DUC/Scores_length_5/DUC_2st_5Sent_lemF_swF_Scores.csv', index_col=0)
fts2 = pd.read_csv(r'DUC/Scores_length_5/DUC_2st_5Sent_lemF_swT_Scores.csv', index_col=0)
tfs2 = pd.read_csv(r'DUC/Scores_length_5/DUC_2st_5Sent_lemT_swF_Scores.csv', index_col=0)
tts2 = pd.read_csv(r'DUC/Scores_length_5/DUC_2st_5Sent_lemT_swT_Scores.csv', index_col=0)

# %%
ffs3 = pd.read_csv(r'DUC/Scores_length_5/DUC_3st_5Sent_lemF_swF_Scores.csv', index_col=0)
fts3 = pd.read_csv(r'DUC/Scores_length_5/DUC_3st_5Sent_lemF_swT_Scores.csv', index_col=0)
tfs3 = pd.read_csv(r'DUC/Scores_length_5/DUC_3st_5Sent_lemT_swF_Scores.csv', index_col=0)
tts3 = pd.read_csv(r'DUC/Scores_length_5/DUC_3st_5Sent_lemT_swT_Scores.csv', index_col=0)

# %%
ffs4 = pd.read_csv(r'DUC/Scores_length_5/DUC_4st_5Sent_lemF_swF_Scores.csv', index_col=0)
fts4 = pd.read_csv(r'DUC/Scores_length_5/DUC_4st_5Sent_lemF_swT_Scores.csv', index_col=0)
tfs4 = pd.read_csv(r'DUC/Scores_length_5/DUC_4st_5Sent_lemT_swF_Scores.csv', index_col=0)
tts4 = pd.read_csv(r'DUC/Scores_length_5/DUC_4st_5Sent_lemT_swT_Scores.csv', index_col=0)

# %%
ffs1 = extracted_number_from_df(ffs1)
ffs2 = extracted_number_from_df(ffs2)
ffs3 = extracted_number_from_df(ffs3)
ffs4 = extracted_number_from_df(ffs4)
avgff = (ffs1 + ffs2 + ffs3 + ffs4)/4

# %%
fts1 = extracted_number_from_df(fts1)
fts2 = extracted_number_from_df(fts2)
fts3 = extracted_number_from_df(fts3)
fts4 = extracted_number_from_df(fts4)
avgft = (fts1 + fts2 + fts3 + fts4)/4

# %%
tfs1 = extracted_number_from_df(tfs1)
tfs2 = extracted_number_from_df(tfs2)
tfs3 = extracted_number_from_df(tfs3)
tfs4 = extracted_number_from_df(tfs4)
avgtf = (tfs1 + tfs2 + tfs3 + tfs4)/4

# %%
tts1 = extracted_number_from_df(tts1)
tts2 = extracted_number_from_df(tts2)
tts3 = extracted_number_from_df(tts3)
tts4 = extracted_number_from_df(tts4)
avgtt = (tts1 + tts2 + tts3 + tts4)/4

# %%
avgft
# Out:
#                     Original Article Original Summary   ('Tm',)  ('Lex',)
# rouge1_fmeasure             0.035975          0.53425   0.30585   0.33285  \
# rouge1_precision            0.018425         0.534825  0.243975  0.298425
# rouge1_recall                0.89665           0.5342    0.4186   0.38625
# rouge2_fmeasure             0.017525           0.3176  0.065975  0.077875
# rouge2_precision            0.008975           0.3177  0.052725  0.069375
# rouge2_recall               0.443425           0.3176    0.0899  0.091125
# rougeL_fmeasure              0.02595           0.4005  0.160375    0.1711
# rougeL_precision              0.0133         0.400675  0.127975    0.1537
# rougeL_recall               0.652025          0.40055    0.2196   0.19825
# rougeLsum_fmeasure          0.034975          0.50615    0.2602    0.2766
# rougeLsum_precision           0.0179         0.506675  0.207675    0.2484
# rougeLsum_recall             0.87195         0.506125    0.3557  0.320225
#
# ...

# %%
avgft
# Out:
#                     Original Article Original Summary   ('Tm',)  ('Lex',)  \
# rouge1_fmeasure             0.035975          0.53425   0.30585   0.33285
# rouge1_precision            0.018425         0.534825  0.243975  0.298425
# rouge1_recall                0.89665           0.5342    0.4186   0.38625
# rouge2_fmeasure             0.017525           0.3176  0.065975  0.077875
# rouge2_precision            0.008975           0.3177  0.052725  0.069375
# rouge2_recall               0.443425           0.3176    0.0899  0.091125
# rougeL_fmeasure              0.02595           0.4005  0.160375    0.1711
# rougeL_precision              0.0133         0.400675  0.127975    0.1537
# rougeL_recall               0.652025          0.40055    0.2196   0.19825
# rougeLsum_fmeasure          0.034975          0.50615    0.2602    0.2766
# rougeLsum_precision           0.0179         0.506675  0.207675    0.2484
# rougeLsum_recall             0.87195         0.506125    0.3557  0.320225
#
# ...
